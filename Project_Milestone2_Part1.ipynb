# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
import statsmodels.formula.api as SM
import sklearn.metrics as metrics
from sklearn.metrics import roc_curve
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import roc_auc_score
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df = pd.read_excel('Company_Data2015-1.xlsx')
df.head()
# Out:
#    Co_Code          Co_Name  Networth Next Year  Equity Paid Up  Networth  \
# 0    16974      Hind.Cables            -8021.60          419.36  -7027.48
# 1    21214  Tata Tele. Mah.            -3986.19         1954.93  -2968.08
# 2    14852     ABG Shipyard            -3192.58           53.84    506.86
# 3     2439              GTL            -3054.51          157.30   -623.49
# 4    23505  Bharati Defence            -2967.36           50.30  -1070.83
#
#    Capital Employed  Total Debt  Gross Block   Net Working Capital   \
# 0          -1007.24     5936.03        474.30              -1076.34
# 1           4458.20     7410.18       9070.86              -1098.88
# 2           7714.68     6944.54       1281.54               4496.25
# 3           2353.88     2326.05       1033.69              -2612.42
# 4           4675.33     5740.90       1084.20               1836.23
#
#    Current Assets   ...  PBIDTM (%)[Latest]  PBITM (%)[Latest]  \
# 0            40.50  ...                0.00               0.00
# 1           486.86  ...              -10.30             -39.74
# 2          9097.64  ...            -5279.14           -5516.98
# 3          1034.12  ...               -3.33              -7.21
# 4          4685.81  ...             -295.55            -400.55
#
#    PBDTM (%)[Latest]  CPM (%)[Latest]  APATM (%)[Latest]  \
# 0               0.00             0.00               0.00
# 1             -57.74           -57.74             -87.18
# 2           -7780.25         -7723.67           -7961.51
# 3             -48.13           -47.70             -51.58
# 4            -845.88           379.79             274.79
#
#    Debtors Velocity (Days)  Creditors Velocity (Days)  \
# 0                        0                          0
# 1                       29                        101
# 2                       97                        558
# 3                       93                         63
# 4                     3887                        346
#
#    Inventory Velocity (Days)  Value of Output/Total Assets  \
# 0                       45.0                          0.00
# 1                        2.0                          0.31
# 2                        0.0                         -0.03
# 3                        2.0                          0.24
# 4                        0.0                          0.01
#
#    Value of Output/Gross Block
# 0                         0.00
# 1                         0.24
# 2                        -0.26
# 3                         1.90
# 4                         0.05
#
# [5 rows x 67 columns]

# %%
df.describe()
# Out:
#             Co_Code  Networth Next Year  Equity Paid Up      Networth  \
# count   3586.000000         3586.000000     3586.000000   3586.000000
# mean   16065.388734          725.045251       62.966584    649.746299
# std    19776.817379         4769.681004      778.761744   4091.988792
# min        4.000000        -8021.600000        0.000000  -7027.480000
# 25%     3029.250000            3.985000        3.750000      3.892500
# 50%     6077.500000           19.015000        8.290000     18.580000
# 75%    24269.500000          123.802500       19.517500    117.297500
# max    72493.000000       111729.100000    42263.460000  81657.350000
#
#        Capital Employed     Total Debt   Gross Block   Net Working Capital   \
# count       3586.000000    3586.000000    3586.000000           3586.000000
# mean        2799.611054    1994.823779     594.178829            410.809665
# std        26975.135385   23652.842746    4871.547802           6301.218546
# min        -1824.750000      -0.720000     -41.190000         -13162.420000
# 25%            7.602500       0.030000       0.570000              0.942500
# 50%           39.090000       7.490000      15.870000             10.145000
# 75%          226.605000      72.350000     131.895000             61.175000
# max       714001.250000  652823.810000  128477.590000         223257.560000
#
#        Current Assets   Current Liabilities and Provisions   ...  \
# count      3586.000000                          3586.000000  ...
# mean       1960.349172                           391.992078  ...
# std       22577.570829                          2675.001631  ...
# min          -0.910000                            -0.230000  ...
# 25%           4.000000                             0.732500  ...
# 50%          24.540000                             9.225000  ...
# 75%         135.277500                            65.650000  ...
# max      721166.000000                         83232.980000  ...
#
#        PBIDTM (%)[Latest]  PBITM (%)[Latest]  PBDTM (%)[Latest]  \
# count         3585.000000        3585.000000        3585.000000
# mean           -51.162890        -109.213414        -311.570357
# std           1795.131025        3057.635870       10921.592639
# min         -78870.450000     -141600.000000     -590500.000000
# 25%              0.000000           0.000000           0.000000
# 50%              8.070000           5.230000           4.690000
# 75%             18.990000          14.290000          14.110000
# max          19233.330000       19195.700000       15640.000000
#
#        CPM (%)[Latest]  APATM (%)[Latest]  Debtors Velocity (Days)  \
# count      3585.000000        3585.000000              3586.000000
# mean       -307.005632        -365.056187               603.894032
# std       10676.149629       12500.051387             10636.759580
# min     -572000.000000     -688600.000000                 0.000000
# 25%           0.000000           0.000000                 8.000000
# 50%           3.890000           1.590000                49.000000
# 75%          11.390000           7.410000               106.000000
# max       15640.000000       15266.670000            514721.000000
#
#        Creditors Velocity (Days)  Inventory Velocity (Days)  \
# count               3.586000e+03                3483.000000
# mean                2.057855e+03                  79.644559
# std                 5.416948e+04                 137.847792
# min                 0.000000e+00                -199.000000
# 25%                 8.000000e+00                   0.000000
# 50%                 3.900000e+01                  35.000000
# 75%                 8.900000e+01                  96.000000
# max                 2.034145e+06                 996.000000
#
#        Value of Output/Total Assets  Value of Output/Gross Block
# count                   3586.000000                  3586.000000
# mean                       0.819757                    61.884548
# std                        1.201400                   976.824352
# min                       -0.330000                   -61.000000
# 25%                        0.070000                     0.270000
# 50%                        0.480000                     1.530000
# 75%                        1.160000                     4.910000
# max                       17.630000                 43404.000000
#
# [8 rows x 66 columns]

# %%
df_dict = pd.read_excel('Data_Dictionary.xlsx')
df_dict
# Out:
#      #                    Field Name  \
# 0    1                       Co_Code
# 1    2                       Co_Name
# 2    3            Networth Next Year
# 3    4                Equity Paid Up
# 4    5                      Networth
# ..  ..                           ...
# 62  64       Debtors Velocity (Days)
# 63  65     Creditors Velocity (Days)
# 64  66     Inventory Velocity (Days)
# 65  67  Value of Output/Total Assets
# 66  68   Value of Output/Gross Block
#
#                                           Description  \
# 0                                        Company Code
# 1                                        Company Name
# 2   Value of a company as on 2016 - Next Year(diff...
# 3   Amount that has been received by the company t...
# 4        Value of a company as on 2015 - Current Year
# ..                                                ...
# 62   Average days required for receiving the payments
# 63  Average number of days company takes to pay su...
# 64  Average number of days the company needs to tu...
# 65  Ratio of Value of Output (market value) to Tot...
# 66  Ratio of Value of Output (market value) to Gro...
#
#                      New Field Name
# 0                           Co_Code
# 1                           Co_Name
# 2                Networth_Next_Year
# 3                    Equity_Paid_Up
# 4                          Networth
# ..                              ...
# 62                 Debtors_Vel_Days
# 63               Creditors_Vel_Days
# 64               Inventory_Vel_Days
# 65  Value_of_Output_to_Total_Assets
# 66   Value_of_Output_to_Gross_Block
#
# [67 rows x 4 columns]

# %%
df.columns = df_dict['New Field Name'].to_list()
df.columns
# Out:
# Index(['Co_Code', 'Co_Name', 'Networth_Next_Year', 'Equity_Paid_Up',
#        'Networth', 'Capital_Employed', 'Total_Debt', 'Gross_Block',
#        'Net_Working_Capital', 'Curr_Assets', 'Curr_Liab_and_Prov',
#        'Total_Assets_to_Liab', 'Gross_Sales', 'Net_Sales', 'Other_Income',
#        'Value_Of_Output', 'Cost_of_Prod', 'Selling_Cost', 'PBIDT', 'PBDT',
#        'PBIT', 'PBT', 'PAT', 'Adjusted_PAT', 'CP', 'Rev_earn_in_forex',
#        'Rev_exp_in_forex', 'Capital_exp_in_forex', 'Book_Value_Unit_Curr',
#        'Book_Value_Adj_Unit_Curr', 'Market_Capitalisation',
#        'CEPS_annualised_Unit_Curr', 'Cash_Flow_From_Opr', 'Cash_Flow_From_Inv',
#        'Cash_Flow_From_Fin', 'ROG_Net_Worth_perc', 'ROG_Capital_Employed_perc',
#        'ROG_Gross_Block_perc', 'ROG_Gross_Sales_perc', 'ROG_Net_Sales_perc',
#        'ROG_Cost_of_Prod_perc', 'ROG_Total_Assets_perc', 'ROG_PBIDT_perc',
#        'ROG_PBDT_perc', 'ROG_PBIT_perc', 'ROG_PBT_perc', 'ROG_PAT_perc',
#        'ROG_CP_perc', 'ROG_Rev_earn_in_forex_perc',
#        'ROG_Rev_exp_in_forex_perc', 'ROG_Market_Capitalisation_perc',
#        'Curr_Ratio_Latest', 'Fixed_Assets_Ratio_Latest',
#        'Inventory_Ratio_Latest', 'Debtors_Ratio_Latest',
#        'Total_Asset_Turnover_Ratio_Latest', 'Interest_Cover_Ratio_Latest',
#        'PBIDTM_perc_Latest', 'PBITM_perc_Latest', 'PBDTM_perc_Latest',
#        'CPM_perc_Latest', 'APATM_perc_Latest', 'Debtors_Vel_Days',
#        'Creditors_Vel_Days', 'Inventory_Vel_Days',
#        'Value_of_Output_to_Total_Assets', 'Value_of_Output_to_Gross_Block'],
#       dtype='object')

# %%
df.shape
# Out:
# (3586, 67)

# %%
df.head()
# Out:
#    Co_Code          Co_Name  Networth_Next_Year  Equity_Paid_Up  Networth  \
# 0    16974      Hind.Cables            -8021.60          419.36  -7027.48
# 1    21214  Tata Tele. Mah.            -3986.19         1954.93  -2968.08
# 2    14852     ABG Shipyard            -3192.58           53.84    506.86
# 3     2439              GTL            -3054.51          157.30   -623.49
# 4    23505  Bharati Defence            -2967.36           50.30  -1070.83
#
#    Capital_Employed  Total_Debt  Gross_Block  Net_Working_Capital  \
# 0          -1007.24     5936.03       474.30             -1076.34
# 1           4458.20     7410.18      9070.86             -1098.88
# 2           7714.68     6944.54      1281.54              4496.25
# 3           2353.88     2326.05      1033.69             -2612.42
# 4           4675.33     5740.90      1084.20              1836.23
#
#    Curr_Assets  ...  PBIDTM_perc_Latest  PBITM_perc_Latest  PBDTM_perc_Latest  \
# 0        40.50  ...                0.00               0.00               0.00
# 1       486.86  ...              -10.30             -39.74             -57.74
# 2      9097.64  ...            -5279.14           -5516.98           -7780.25
# 3      1034.12  ...               -3.33              -7.21             -48.13
# 4      4685.81  ...             -295.55            -400.55            -845.88
#
#    CPM_perc_Latest  APATM_perc_Latest  Debtors_Vel_Days  Creditors_Vel_Days  \
# 0             0.00               0.00                 0                   0
# 1           -57.74             -87.18                29                 101
# 2         -7723.67           -7961.51                97                 558
# 3           -47.70             -51.58                93                  63
# 4           379.79             274.79              3887                 346
#
#    Inventory_Vel_Days  Value_of_Output_to_Total_Assets  \
# 0                45.0                             0.00
# 1                 2.0                             0.31
# 2                 0.0                            -0.03
# 3                 2.0                             0.24
# 4                 0.0                             0.01
#
#    Value_of_Output_to_Gross_Block
# 0                            0.00
# 1                            0.24
# 2                           -0.26
# 3                            1.90
# 4                            0.05
#
# [5 rows x 67 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3586 entries, 0 to 3585
# Data columns (total 67 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Co_Code                            3586 non-null   int64
#  1   Co_Name                            3586 non-null   object
#  2   Networth_Next_Year                 3586 non-null   float64
#  3   Equity_Paid_Up                     3586 non-null   float64
#  4   Networth                           3586 non-null   float64
#  5   Capital_Employed                   3586 non-null   float64
#  6   Total_Debt                         3586 non-null   float64
#  7   Gross_Block                        3586 non-null   float64
#  8   Net_Working_Capital                3586 non-null   float64
#  9   Curr_Assets                        3586 non-null   float64
#  10  Curr_Liab_and_Prov                 3586 non-null   float64
#  11  Total_Assets_to_Liab               3586 non-null   float64
#  12  Gross_Sales                        3586 non-null   float64
#  13  Net_Sales                          3586 non-null   float64
#  14  Other_Income                       3586 non-null   float64
#  15  Value_Of_Output                    3586 non-null   float64
#  16  Cost_of_Prod                       3586 non-null   float64
#  17  Selling_Cost                       3586 non-null   float64
#  18  PBIDT                              3586 non-null   float64
#  19  PBDT                               3586 non-null   float64
#  20  PBIT                               3586 non-null   float64
#  21  PBT                                3586 non-null   float64
#  22  PAT                                3586 non-null   float64
#  23  Adjusted_PAT                       3586 non-null   float64
#  24  CP                                 3586 non-null   float64
#  25  Rev_earn_in_forex                  3586 non-null   float64
#  26  Rev_exp_in_forex                   3586 non-null   float64
#  27  Capital_exp_in_forex               3586 non-null   float64
#  28  Book_Value_Unit_Curr               3586 non-null   float64
#  29  Book_Value_Adj_Unit_Curr           3582 non-null   float64
#  30  Market_Capitalisation              3586 non-null   float64
#  31  CEPS_annualised_Unit_Curr          3586 non-null   float64
#  32  Cash_Flow_From_Opr                 3586 non-null   float64
#  33  Cash_Flow_From_Inv                 3586 non-null   float64
#  34  Cash_Flow_From_Fin                 3586 non-null   float64
#  35  ROG_Net_Worth_perc                 3586 non-null   float64
#  36  ROG_Capital_Employed_perc          3586 non-null   float64
#  37  ROG_Gross_Block_perc               3586 non-null   float64
#  38  ROG_Gross_Sales_perc               3586 non-null   float64
#  39  ROG_Net_Sales_perc                 3586 non-null   float64
#  40  ROG_Cost_of_Prod_perc              3586 non-null   float64
#  41  ROG_Total_Assets_perc              3586 non-null   float64
#  42  ROG_PBIDT_perc                     3586 non-null   float64
#  43  ROG_PBDT_perc                      3586 non-null   float64
#  44  ROG_PBIT_perc                      3586 non-null   float64
#  45  ROG_PBT_perc                       3586 non-null   float64
#  46  ROG_PAT_perc                       3586 non-null   float64
#  47  ROG_CP_perc                        3586 non-null   float64
#  48  ROG_Rev_earn_in_forex_perc         3586 non-null   float64
#  49  ROG_Rev_exp_in_forex_perc          3586 non-null   float64
#  50  ROG_Market_Capitalisation_perc     3586 non-null   float64
#  51  Curr_Ratio_Latest                  3585 non-null   float64
#  52  Fixed_Assets_Ratio_Latest          3585 non-null   float64
#  53  Inventory_Ratio_Latest             3585 non-null   float64
#  54  Debtors_Ratio_Latest               3585 non-null   float64
#  55  Total_Asset_Turnover_Ratio_Latest  3585 non-null   float64
#  56  Interest_Cover_Ratio_Latest        3585 non-null   float64
#  57  PBIDTM_perc_Latest                 3585 non-null   float64
#  58  PBITM_perc_Latest                  3585 non-null   float64
#  59  PBDTM_perc_Latest                  3585 non-null   float64
#  60  CPM_perc_Latest                    3585 non-null   float64
#  61  APATM_perc_Latest                  3585 non-null   float64
#  62  Debtors_Vel_Days                   3586 non-null   int64
#  63  Creditors_Vel_Days                 3586 non-null   int64
#  64  Inventory_Vel_Days                 3483 non-null   float64
#  65  Value_of_Output_to_Total_Assets    3586 non-null   float64
#  66  Value_of_Output_to_Gross_Block     3586 non-null   float64
# dtypes: float64(63), int64(3), object(1)
# memory usage: 1.8+ MB

# %%
import missingno as msno
msno.matrix(df)

# %%
pd.set_option('display.max_rows', 500)

# %%
df.isna().sum()
# Out:
# Co_Code                                0
# Co_Name                                0
# Networth_Next_Year                     0
# Equity_Paid_Up                         0
# Networth                               0
# Capital_Employed                       0
# Total_Debt                             0
# Gross_Block                            0
# Net_Working_Capital                    0
# Curr_Assets                            0
# Curr_Liab_and_Prov                     0
# Total_Assets_to_Liab                   0
# Gross_Sales                            0
# Net_Sales                              0
# Other_Income                           0
# Value_Of_Output                        0
# Cost_of_Prod                           0
# Selling_Cost                           0
# PBIDT                                  0
# PBDT                                   0
# PBIT                                   0
# PBT                                    0
# PAT                                    0
# Adjusted_PAT                           0
# CP                                     0
# Rev_earn_in_forex                      0
# Rev_exp_in_forex                       0
# Capital_exp_in_forex                   0
# Book_Value_Unit_Curr                   0
# Book_Value_Adj_Unit_Curr               4
# Market_Capitalisation                  0
# CEPS_annualised_Unit_Curr              0
# Cash_Flow_From_Opr                     0
# Cash_Flow_From_Inv                     0
# Cash_Flow_From_Fin                     0
# ROG_Net_Worth_perc                     0
# ROG_Capital_Employed_perc              0
# ROG_Gross_Block_perc                   0
# ROG_Gross_Sales_perc                   0
# ROG_Net_Sales_perc                     0
# ROG_Cost_of_Prod_perc                  0
# ROG_Total_Assets_perc                  0
# ROG_PBIDT_perc                         0
# ROG_PBDT_perc                          0
# ROG_PBIT_perc                          0
# ROG_PBT_perc                           0
# ROG_PAT_perc                           0
# ROG_CP_perc                            0
# ROG_Rev_earn_in_forex_perc             0
# ROG_Rev_exp_in_forex_perc              0
# ROG_Market_Capitalisation_perc         0
# Curr_Ratio_Latest                      1
# Fixed_Assets_Ratio_Latest              1
# Inventory_Ratio_Latest                 1
# Debtors_Ratio_Latest                   1
# Total_Asset_Turnover_Ratio_Latest      1
# Interest_Cover_Ratio_Latest            1
# PBIDTM_perc_Latest                     1
# PBITM_perc_Latest                      1
# PBDTM_perc_Latest                      1
# CPM_perc_Latest                        1
# APATM_perc_Latest                      1
# Debtors_Vel_Days                       0
# Creditors_Vel_Days                     0
# Inventory_Vel_Days                   103
# Value_of_Output_to_Total_Assets        0
# Value_of_Output_to_Gross_Block         0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Co_Code                                0
# Co_Name                                0
# Networth_Next_Year                     0
# Equity_Paid_Up                         0
# Networth                               0
# Capital_Employed                       0
# Total_Debt                             0
# Gross_Block                            0
# Net_Working_Capital                    0
# Curr_Assets                            0
# Curr_Liab_and_Prov                     0
# Total_Assets_to_Liab                   0
# Gross_Sales                            0
# Net_Sales                              0
# Other_Income                           0
# Value_Of_Output                        0
# Cost_of_Prod                           0
# Selling_Cost                           0
# PBIDT                                  0
# PBDT                                   0
# PBIT                                   0
# PBT                                    0
# PAT                                    0
# Adjusted_PAT                           0
# CP                                     0
# Rev_earn_in_forex                      0
# Rev_exp_in_forex                       0
# Capital_exp_in_forex                   0
# Book_Value_Unit_Curr                   0
# Book_Value_Adj_Unit_Curr               4
# Market_Capitalisation                  0
# CEPS_annualised_Unit_Curr              0
# Cash_Flow_From_Opr                     0
# Cash_Flow_From_Inv                     0
# Cash_Flow_From_Fin                     0
# ROG_Net_Worth_perc                     0
# ROG_Capital_Employed_perc              0
# ROG_Gross_Block_perc                   0
# ROG_Gross_Sales_perc                   0
# ROG_Net_Sales_perc                     0
# ROG_Cost_of_Prod_perc                  0
# ROG_Total_Assets_perc                  0
# ROG_PBIDT_perc                         0
# ROG_PBDT_perc                          0
# ROG_PBIT_perc                          0
# ROG_PBT_perc                           0
# ROG_PAT_perc                           0
# ROG_CP_perc                            0
# ROG_Rev_earn_in_forex_perc             0
# ROG_Rev_exp_in_forex_perc              0
# ROG_Market_Capitalisation_perc         0
# Curr_Ratio_Latest                      1
# Fixed_Assets_Ratio_Latest              1
# Inventory_Ratio_Latest                 1
# Debtors_Ratio_Latest                   1
# Total_Asset_Turnover_Ratio_Latest      1
# Interest_Cover_Ratio_Latest            1
# PBIDTM_perc_Latest                     1
# PBITM_perc_Latest                      1
# PBDTM_perc_Latest                      1
# CPM_perc_Latest                        1
# APATM_perc_Latest                      1
# Debtors_Vel_Days                       0
# Creditors_Vel_Days                     0
# Inventory_Vel_Days                   103
# Value_of_Output_to_Total_Assets        0
# Value_of_Output_to_Gross_Block         0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 118

# %%
df.shape
# Out:
# (3586, 67)

# %%
df.dropna().shape
# Out:
# (3478, 67)

# %% [markdown]
# ### Treating missing values in Inventory_Vel_Days variable

# %%
df['Inventory_Vel_Days'].fillna(df['Inventory_Vel_Days'].mean(), inplace = True)

# %%
df.isna().sum().sum()
# Out:
# 15

# %% [markdown]
# ### Dropping rows with missing values after fixing Inventory_Vel_Days variable

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (3581, 67)

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Cehcking for duplicate data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Dropping unrequired columns

# %%
df = df.drop(['Co_Code', 'Co_Name'], axis = 1)
df.head()
# Out:
#    Networth_Next_Year  Equity_Paid_Up  Networth  Capital_Employed  Total_Debt  \
# 0            -8021.60          419.36  -7027.48          -1007.24     5936.03
# 1            -3986.19         1954.93  -2968.08           4458.20     7410.18
# 2            -3192.58           53.84    506.86           7714.68     6944.54
# 3            -3054.51          157.30   -623.49           2353.88     2326.05
# 4            -2967.36           50.30  -1070.83           4675.33     5740.90
#
#    Gross_Block  Net_Working_Capital  Curr_Assets  Curr_Liab_and_Prov  \
# 0       474.30             -1076.34        40.50             1116.85
# 1      9070.86             -1098.88       486.86             1585.74
# 2      1281.54              4496.25      9097.64             4601.39
# 3      1033.69             -2612.42      1034.12             3646.54
# 4      1084.20              1836.23      4685.81             2849.58
#
#    Total_Assets_to_Liab  ...  PBIDTM_perc_Latest  PBITM_perc_Latest  \
# 0                109.60  ...                0.00               0.00
# 1               6043.94  ...              -10.30             -39.74
# 2              12316.07  ...            -5279.14           -5516.98
# 3               6000.42  ...               -3.33              -7.21
# 4               7524.91  ...             -295.55            -400.55
#
#    PBDTM_perc_Latest  CPM_perc_Latest  APATM_perc_Latest  Debtors_Vel_Days  \
# 0               0.00             0.00               0.00                 0
# 1             -57.74           -57.74             -87.18                29
# 2           -7780.25         -7723.67           -7961.51                97
# 3             -48.13           -47.70             -51.58                93
# 4            -845.88           379.79             274.79              3887
#
#    Creditors_Vel_Days  Inventory_Vel_Days  Value_of_Output_to_Total_Assets  \
# 0                   0                45.0                             0.00
# 1                 101                 2.0                             0.31
# 2                 558                 0.0                            -0.03
# 3                  63                 2.0                             0.24
# 4                 346                 0.0                             0.01
#
#    Value_of_Output_to_Gross_Block
# 0                            0.00
# 1                            0.24
# 2                           -0.26
# 3                            1.90
# 4                            0.05
#
# [5 rows x 65 columns]

# %% [markdown]
# ## Checking distribution of all variables

# %%
fig, ax = plt.subplots(figsize = (20, 100), nrows = 22, ncols = 3)

for i, col in enumerate(df.columns):
        sns.distplot(df[col], ax = ax[i//3, i%3], kde = False, color = 'blue')

# %% [markdown]
# ## Checking skewness in the data

# %%
pd.DataFrame(df.skew().sort_values(ascending=False),columns=['Skewness'])
# Out:
#                                     Skewness
# Book_Value_Adj_Unit_Curr           59.835459
# ROG_PBIT_perc                      58.884442
# ROG_PBIDT_perc                     58.839674
# ROG_PBDT_perc                      58.366940
# ROG_PBT_perc                       57.292161
# ROG_Market_Capitalisation_perc     57.290651
# ROG_Total_Assets_perc              57.264557
# ROG_Rev_exp_in_forex_perc          56.767771
# ROG_CP_perc                        56.749344
# ROG_Capital_Employed_perc          56.397091
# ROG_PAT_perc                       52.606895
# CEPS_annualised_Unit_Curr          48.499662
# Equity_Paid_Up                     45.897050
# ROG_Net_Sales_perc                 45.373973
# ROG_Gross_Sales_perc               45.373047
# ROG_Gross_Block_perc               44.839948
# ROG_Net_Worth_perc                 44.800706
# Interest_Cover_Ratio_Latest        40.801193
# Debtors_Vel_Days                   38.633905
# ROG_Cost_of_Prod_perc              37.243494
# Debtors_Ratio_Latest               35.236850
# Rev_exp_in_forex                   34.817286
# Cost_of_Prod                       34.564594
# Creditors_Vel_Days                 34.097478
# Book_Value_Unit_Curr               32.961635
# Value_of_Output_to_Gross_Block     31.976222
# Gross_Sales                        31.538417
# Curr_Ratio_Latest                  31.264765
# Net_Sales                          31.063594
# ROG_Rev_earn_in_forex_perc         31.030547
# Value_Of_Output                    30.790974
# Net_Working_Capital                30.559236
# Capital_exp_in_forex               27.591003
# Inventory_Ratio_Latest             26.987799
# Rev_earn_in_forex                  24.159618
# Fixed_Assets_Ratio_Latest          24.109628
# Curr_Assets                        20.764954
# Total_Debt                         19.404026
# Selling_Cost                       18.865968
# Other_Income                       18.792561
# Gross_Block                        18.515689
# Capital_Employed                   18.061056
# Curr_Liab_and_Prov                 15.280793
# Market_Capitalisation              14.381041
# CP                                 14.335178
# PBIT                               13.999627
# Adjusted_PAT                       13.865880
# PBDT                               13.545492
# Total_Assets_to_Liab               13.358549
# PBIDT                              13.169771
# PBT                                13.118280
# PAT                                13.058587
# Networth_Next_Year                 13.032120
# Networth                           11.730548
# Total_Asset_Turnover_Ratio_Latest  10.354365
# Cash_Flow_From_Opr                  6.630075
# Value_of_Output_to_Total_Assets     4.708705
# Inventory_Vel_Days                  3.547576
# Cash_Flow_From_Fin                  1.702510
# Cash_Flow_From_Inv                -21.550029
# PBIDTM_perc_Latest                -30.914273
# PBITM_perc_Latest                 -35.977753
# CPM_perc_Latest                   -46.985387
# PBDTM_perc_Latest                 -47.723669
# APATM_perc_Latest                 -49.249980

# %% [markdown]
# ## Outlier Analysis

# %%
#outlier analysis

q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
med = df.median()
IQR = q3 - q1

#checking extreme outliers (3x)
upper_limit = q3 + (3 * IQR)   
lower_limit = q1 - (3 * IQR)

# %% [markdown]
# ### What percent of values in each column are outliers

# %%
((df > upper_limit).sum()/len(df)*100).sort_values(ascending=False)
# Out:
# ROG_Rev_exp_in_forex_perc            22.926557
# Capital_exp_in_forex                 19.380061
# ROG_Rev_earn_in_forex_perc           17.900028
# Rev_earn_in_forex                    17.648701
# Rev_exp_in_forex                     16.727171
# PAT                                  14.884111
# Market_Capitalisation                14.744485
# PBT                                  14.688634
# Adjusted_PAT                         14.632784
# CP                                   14.325607
# PBDT                                 14.074281
# PBIT                                 13.683329
# PBIDT                                13.655404
# Selling_Cost                         13.292376
# Other_Income                         13.236526
# Cash_Flow_From_Opr                   13.068975
# Networth_Next_Year                   13.041050
# Total_Debt                           12.901424
# Networth                             12.566322
# Capital_Employed                     12.538397
# Curr_Ratio_Latest                    12.510472
# Curr_Liab_and_Prov                   12.259145
# Curr_Assets                          12.007819
# Total_Assets_to_Liab                 11.979894
# Value_Of_Output                      11.616867
# Gross_Sales                          11.616867
# Net_Sales                            11.533091
# Cost_of_Prod                         11.281765
# Interest_Cover_Ratio_Latest          11.253840
# Net_Working_Capital                  11.253840
# Gross_Block                          10.639486
# Value_of_Output_to_Gross_Block       10.360235
# Fixed_Assets_Ratio_Latest            10.276459
# Equity_Paid_Up                        9.075677
# ROG_Gross_Block_perc                  9.047752
# CEPS_annualised_Unit_Curr             8.461324
# ROG_Cost_of_Prod_perc                 8.433398
# Cash_Flow_From_Fin                    7.958671
# Creditors_Vel_Days                    7.735269
# Debtors_Vel_Days                      7.707344
# ROG_Gross_Sales_perc                  7.679419
# ROG_Net_Sales_perc                    7.651494
# ROG_Net_Worth_perc                    7.511868
# Book_Value_Unit_Curr                  7.456018
# APATM_perc_Latest                     7.148841
# Book_Value_Adj_Unit_Curr              7.065066
# Inventory_Ratio_Latest                6.925440
# ROG_Market_Capitalisation_perc        6.841664
# PBITM_perc_Latest                     6.590338
# Debtors_Ratio_Latest                  6.478637
# ROG_PBIDT_perc                        6.478637
# ROG_PBIT_perc                         6.115610
# ROG_Capital_Employed_perc             6.003910
# ROG_PBDT_perc                         5.640882
# ROG_CP_perc                           5.473331
# CPM_perc_Latest                       5.445406
# ROG_Total_Assets_perc                 5.333706
# ROG_PAT_perc                          5.249930
# PBDTM_perc_Latest                     5.222005
# ROG_PBT_perc                          5.026529
# Cash_Flow_From_Inv                    4.691427
# PBIDTM_perc_Latest                    4.495951
# Inventory_Vel_Days                    3.937448
# Total_Asset_Turnover_Ratio_Latest     2.429489
# Value_of_Output_to_Total_Assets       1.480034
# dtype: float64

# %%
((df < lower_limit).sum()/len(df)*100).sort_values(ascending=False)
# Out:
# ROG_Rev_exp_in_forex_perc            22.172577
# ROG_Rev_earn_in_forex_perc           18.877409
# Cash_Flow_From_Inv                   14.800335
# Cash_Flow_From_Fin                   13.739179
# APATM_perc_Latest                    11.309690
# CPM_perc_Latest                       8.209997
# PBDTM_perc_Latest                     7.595644
# PBITM_perc_Latest                     7.176766
# ROG_Gross_Block_perc                  7.092991
# Adjusted_PAT                          6.785814
# PAT                                   6.646188
# ROG_Net_Worth_perc                    6.450712
# ROG_PBT_perc                          6.087685
# PBT                                   6.059760
# ROG_PAT_perc                          5.836359
# ROG_CP_perc                           5.585032
# ROG_PBDT_perc                         5.473331
# PBIDTM_perc_Latest                    5.110304
# ROG_PBIT_perc                         4.691427
# ROG_PBIDT_perc                        4.300475
# Interest_Cover_Ratio_Latest           3.797822
# PBDT                                  3.769897
# CP                                    3.630271
# Cash_Flow_From_Opr                    3.546495
# ROG_Capital_Employed_perc             2.624965
# ROG_Gross_Sales_perc                  2.261938
# ROG_Net_Sales_perc                    2.234013
# PBIT                                  2.122312
# Net_Working_Capital                   1.787210
# CEPS_annualised_Unit_Curr             1.703435
# ROG_Total_Assets_perc                 1.452108
# PBIDT                                 1.396258
# Networth_Next_Year                    1.172857
# ROG_Cost_of_Prod_perc                 0.977381
# Networth                              0.837755
# Book_Value_Adj_Unit_Curr              0.781904
# Book_Value_Unit_Curr                  0.670204
# Capital_Employed                      0.055850
# Value_of_Output_to_Gross_Block        0.055850
# Other_Income                          0.027925
# Equity_Paid_Up                        0.000000
# Total_Debt                            0.000000
# Value_Of_Output                       0.000000
# Inventory_Vel_Days                    0.000000
# Curr_Assets                           0.000000
# Curr_Liab_and_Prov                    0.000000
# Total_Assets_to_Liab                  0.000000
# Gross_Sales                           0.000000
# Net_Sales                             0.000000
# Gross_Block                           0.000000
# Value_of_Output_to_Total_Assets       0.000000
# Cost_of_Prod                          0.000000
# Creditors_Vel_Days                    0.000000
# Debtors_Vel_Days                      0.000000
# Total_Asset_Turnover_Ratio_Latest     0.000000
# Debtors_Ratio_Latest                  0.000000
# Inventory_Ratio_Latest                0.000000
# Fixed_Assets_Ratio_Latest             0.000000
# Curr_Ratio_Latest                     0.000000
# Rev_earn_in_forex                     0.000000
# Rev_exp_in_forex                      0.000000
# Capital_exp_in_forex                  0.000000
# Market_Capitalisation                 0.000000
# ROG_Market_Capitalisation_perc        0.000000
# Selling_Cost                          0.000000
# dtype: float64

# %%
(((df>upper_limit).sum()+(df<lower_limit).sum())/len(df)*100).sort_values(ascending=False)
# Out:
# ROG_Rev_exp_in_forex_perc            45.099134
# ROG_Rev_earn_in_forex_perc           36.777436
# Cash_Flow_From_Fin                   21.697850
# PAT                                  21.530299
# Adjusted_PAT                         21.418598
# PBT                                  20.748394
# Cash_Flow_From_Inv                   19.491762
# Capital_exp_in_forex                 19.380061
# APATM_perc_Latest                    18.458531
# CP                                   17.955878
# PBDT                                 17.844178
# Rev_earn_in_forex                    17.648701
# Rev_exp_in_forex                     16.727171
# Cash_Flow_From_Opr                   16.615471
# ROG_Gross_Block_perc                 16.140743
# PBIT                                 15.805641
# Interest_Cover_Ratio_Latest          15.051662
# PBIDT                                15.051662
# Market_Capitalisation                14.744485
# Networth_Next_Year                   14.213907
# ROG_Net_Worth_perc                   13.962580
# PBITM_perc_Latest                    13.767104
# CPM_perc_Latest                      13.655404
# Networth                             13.404077
# Selling_Cost                         13.292376
# Other_Income                         13.264451
# Net_Working_Capital                  13.041050
# Total_Debt                           12.901424
# PBDTM_perc_Latest                    12.817649
# Capital_Employed                     12.594247
# Curr_Ratio_Latest                    12.510472
# Curr_Liab_and_Prov                   12.259145
# Curr_Assets                          12.007819
# Total_Assets_to_Liab                 11.979894
# Gross_Sales                          11.616867
# Value_Of_Output                      11.616867
# Net_Sales                            11.533091
# Cost_of_Prod                         11.281765
# ROG_PBDT_perc                        11.114214
# ROG_PBT_perc                         11.114214
# ROG_PAT_perc                         11.086289
# ROG_CP_perc                          11.058364
# ROG_PBIT_perc                        10.807037
# ROG_PBIDT_perc                       10.779112
# Gross_Block                          10.639486
# Value_of_Output_to_Gross_Block       10.416085
# Fixed_Assets_Ratio_Latest            10.276459
# CEPS_annualised_Unit_Curr            10.164758
# ROG_Gross_Sales_perc                  9.941357
# ROG_Net_Sales_perc                    9.885507
# PBIDTM_perc_Latest                    9.606255
# ROG_Cost_of_Prod_perc                 9.410779
# Equity_Paid_Up                        9.075677
# ROG_Capital_Employed_perc             8.628875
# Book_Value_Unit_Curr                  8.126222
# Book_Value_Adj_Unit_Curr              7.846970
# Creditors_Vel_Days                    7.735269
# Debtors_Vel_Days                      7.707344
# Inventory_Ratio_Latest                6.925440
# ROG_Market_Capitalisation_perc        6.841664
# ROG_Total_Assets_perc                 6.785814
# Debtors_Ratio_Latest                  6.478637
# Inventory_Vel_Days                    3.937448
# Total_Asset_Turnover_Ratio_Latest     2.429489
# Value_of_Output_to_Total_Assets       1.480034
# dtype: float64

# %% [markdown]
# ## Since there are a significant number of records which are outliers, it will change the essence of the data, if we treat outliers. Also the outliers are present due to the nature of the data which comprises small as well as big companies, hence the disparity

# %%
#boxplots with extreme whiskers (+/- 3*IQR)

fig, ax = plt.subplots(figsize = (20, 120), nrows = 33, ncols = 2)

for i, col in enumerate(df.columns):
    sns.boxplot(x = df[col], ax = ax[i//2, i%2], whis = 3) #extreme whiskers
    
plt.tight_layout(pad = 1.1)

# %% [markdown]
# ## Heatmap

# %%
sns.clustermap(df.corr(),figsize=(20,20))

# %% [markdown]
# ## Analysing Networth_Next_Year variable, since on the basis of this variable we will define the dependent variable

# %%
fig, ax = plt.subplots(figsize = (20, 180), nrows = 33, ncols = 2)

for i, col in enumerate(df.columns):
    sns.regplot(x = df[col], y = df['Networth_Next_Year'], ax = ax[i//2, i%2])
    
plt.tight_layout(pad = 1.1)

# %% [markdown]
# ## Making the dependent Variable

# %%
df['Default']=np.where(df['Networth_Next_Year']<0,1,0)

# %%
df.head()
# Out:
#    Networth_Next_Year  Equity_Paid_Up  Networth  Capital_Employed  Total_Debt  \
# 0            -8021.60          419.36  -7027.48          -1007.24     5936.03
# 1            -3986.19         1954.93  -2968.08           4458.20     7410.18
# 2            -3192.58           53.84    506.86           7714.68     6944.54
# 3            -3054.51          157.30   -623.49           2353.88     2326.05
# 4            -2967.36           50.30  -1070.83           4675.33     5740.90
#
#    Gross_Block  Net_Working_Capital  Curr_Assets  Curr_Liab_and_Prov  \
# 0       474.30             -1076.34        40.50             1116.85
# 1      9070.86             -1098.88       486.86             1585.74
# 2      1281.54              4496.25      9097.64             4601.39
# 3      1033.69             -2612.42      1034.12             3646.54
# 4      1084.20              1836.23      4685.81             2849.58
#
#    Total_Assets_to_Liab  ...  PBITM_perc_Latest  PBDTM_perc_Latest  \
# 0                109.60  ...               0.00               0.00
# 1               6043.94  ...             -39.74             -57.74
# 2              12316.07  ...           -5516.98           -7780.25
# 3               6000.42  ...              -7.21             -48.13
# 4               7524.91  ...            -400.55            -845.88
#
#    CPM_perc_Latest  APATM_perc_Latest  Debtors_Vel_Days  Creditors_Vel_Days  \
# 0             0.00               0.00                 0                   0
# 1           -57.74             -87.18                29                 101
# 2         -7723.67           -7961.51                97                 558
# 3           -47.70             -51.58                93                  63
# 4           379.79             274.79              3887                 346
#
#    Inventory_Vel_Days  Value_of_Output_to_Total_Assets  \
# 0                45.0                             0.00
# 1                 2.0                             0.31
# 2                 0.0                            -0.03
# 3                 2.0                             0.24
# 4                 0.0                             0.01
#
#    Value_of_Output_to_Gross_Block  Default
# 0                            0.00        1
# 1                            0.24        1
# 2                           -0.26        1
# 3                            1.90        1
# 4                            0.05        1
#
# [5 rows x 66 columns]

# %% [markdown]
# ## Converting to X and y

# %%
X = df.drop('Default', axis = 1)
y = df['Default']

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Since there are too many columns, we need to determine the columns which are related and eliminate them if possible. We will use VIF to determine the collinearity and eliminate using a threshold of 5.

# %%
#vif calculation

def calculate_vif_(X, thresh = 5):
    cols = X.columns
    variables = np.arange(X.shape[1])
    dropped=True
    while dropped:
        dropped=False
        c = X[cols[variables]].values
        vif = [variance_inflation_factor(c, ix) for ix in np.arange(c.shape[1])]

        maxloc = vif.index(max(vif))
        if max(vif) > thresh:
            print('dropping \'' + X[cols[variables]].columns[maxloc] + '\' at index: ' + str(maxloc))
            variables = np.delete(variables, maxloc)
            dropped=True
    
    
    print('Remaining variables:')
    print(X.columns[variables])
    return X[cols[variables]]

# %%
X=calculate_vif_(X,5)
# Out:
# dropping 'PBIDT' at index: 16
# dropping 'PBDT' at index: 16
# dropping 'APATM_perc_Latest' at index: 57
# dropping 'ROG_Gross_Sales_perc' at index: 34
# dropping 'Net_Sales' at index: 11
# dropping 'PBDTM_perc_Latest' at index: 53
# dropping 'Value_Of_Output' at index: 12
# dropping 'ROG_Total_Assets_perc' at index: 34
# dropping 'Capital_Employed' at index: 3
# dropping 'Gross_Sales' at index: 9
# dropping 'Total_Debt' at index: 3
# dropping 'ROG_PBDT_perc' at index: 32
# dropping 'ROG_PBIT_perc' at index: 32
# dropping 'CP' at index: 15
# dropping 'PAT' at index: 13
# dropping 'ROG_PBIDT_perc' at index: 29
# dropping 'Total_Assets_to_Liab' at index: 7
# dropping 'ROG_PBT_perc' at index: 28
# dropping 'PBT' at index: 11
# dropping 'PBIT' at index: 10
# dropping 'Cost_of_Prod' at index: 8
# dropping 'Networth' at index: 2
# dropping 'PBITM_perc_Latest' at index: 36
# dropping 'ROG_CP_perc' at index: 25
# dropping 'Cash_Flow_From_Fin' at index: 18
# dropping 'ROG_Net_Worth_perc' at index: 18
# dropping 'Gross_Block' at index: 2
# dropping 'Fixed_Assets_Ratio_Latest' at index: 26
# dropping 'Curr_Liab_and_Prov' at index: 4
# dropping 'Networth_Next_Year' at index: 0
# dropping 'Adjusted_PAT' at index: 5
# Remaining variables:
# Index(['Equity_Paid_Up', 'Net_Working_Capital', 'Curr_Assets', 'Other_Income',
#        'Selling_Cost', 'Rev_earn_in_forex', 'Rev_exp_in_forex',
#        'Capital_exp_in_forex', 'Book_Value_Unit_Curr',
#        'Book_Value_Adj_Unit_Curr', 'Market_Capitalisation',
#        'CEPS_annualised_Unit_Curr', 'Cash_Flow_From_Opr', 'Cash_Flow_From_Inv',
#        'ROG_Capital_Employed_perc', 'ROG_Gross_Block_perc',
#        'ROG_Net_Sales_perc', 'ROG_Cost_of_Prod_perc', 'ROG_PAT_perc',
#        'ROG_Rev_earn_in_forex_perc', 'ROG_Rev_exp_in_forex_perc',
#        'ROG_Market_Capitalisation_perc', 'Curr_Ratio_Latest',
#        'Inventory_Ratio_Latest', 'Debtors_Ratio_Latest',
#        'Total_Asset_Turnover_Ratio_Latest', 'Interest_Cover_Ratio_Latest',
#        'PBIDTM_perc_Latest', 'CPM_perc_Latest', 'Debtors_Vel_Days',
#        'Creditors_Vel_Days', 'Inventory_Vel_Days',
#        'Value_of_Output_to_Total_Assets', 'Value_of_Output_to_Gross_Block'],
#       dtype='object')

# %%
X
# Out:
#       Equity_Paid_Up  Net_Working_Capital  Curr_Assets  Other_Income  \
# 0             419.36             -1076.34        40.50          7.60
# 1            1954.93             -1098.88       486.86         46.27
# 2              53.84              4496.25      9097.64          9.55
# 3             157.30             -2612.42      1034.12        223.85
# 4              50.30              1836.23      4685.81          9.82
# ...              ...                  ...          ...           ...
# 3581          501.30                 0.00    444633.50       8996.35
# 3582          296.50              2503.86     11554.45       2008.86
# 3583         2427.95              6376.84     89609.82       5815.66
# 3584         8245.46             11449.79     42353.59       2399.39
# 3585         1998.70            -12145.30     11947.10       5193.00
#
#       Selling_Cost  Rev_earn_in_forex  Rev_exp_in_forex  Capital_exp_in_forex  \
# 0             0.00               0.00              0.00                  0.00
# 1            40.51               6.35            143.42                141.17
# 2            54.83               0.00             86.36                  2.27
# 3             3.34               0.89             28.88                  0.00
# 4             1.97               0.00             15.62                  0.00
# ...            ...                ...               ...                   ...
# 3581        187.47               0.00              0.00                  0.00
# 3582        249.20           14429.18          19525.06                 11.30
# 3583        686.53           16009.99         193979.73                294.88
# 3584         71.22               3.41            962.27               2788.44
# 3585       1555.50            3727.40           3017.20               3722.10
#
#       Book_Value_Unit_Curr  Book_Value_Adj_Unit_Curr  ...  \
# 0                  -167.58                   -167.58  ...
# 1                   -15.18                    -15.18  ...
# 2                    94.14                     94.14  ...
# 3                   -39.64                    -39.64  ...
# 4                  -212.89                   -212.89  ...
# ...                    ...                       ...  ...
# 3581                247.39                    247.39  ...
# 3582                114.87                    114.87  ...
# 3583                279.95                     69.99  ...
# 3584                 99.03                     99.03  ...
# 3585                195.80                    195.80  ...
#
#       Debtors_Ratio_Latest  Total_Asset_Turnover_Ratio_Latest  \
# 0                     0.00                               0.00
# 1                    10.35                               0.30
# 2                     0.42                               0.00
# 3                     9.26                               0.00
# 4                     1.28                               0.01
# ...                    ...                                ...
# 3581                  0.00                               0.00
# 3582                 22.31                               0.30
# 3583                 55.49                               2.62
# 3584                  9.86                               0.39
# 3585                 19.51                               0.38
#
#       Interest_Cover_Ratio_Latest  PBIDTM_perc_Latest  CPM_perc_Latest  \
# 0                           -0.20                0.00             0.00
# 1                           -0.84              -10.30           -57.74
# 2                           -2.21            -5279.14         -7723.67
# 3                           -0.16               -3.33           -47.70
# 4                           -0.73             -295.55           379.79
# ...                           ...                 ...              ...
# 3581                         0.00                0.00             0.00
# 3582                         3.18               39.92            30.52
# 3583                         8.60                8.09             5.69
# 3584                         4.35               28.12            19.55
# 3585                         2.71               42.47            25.97
#
#       Debtors_Vel_Days  Creditors_Vel_Days  Inventory_Vel_Days  \
# 0                    0                   0           45.000000
# 1                   29                 101            2.000000
# 2                   97                 558            0.000000
# 3                   93                  63            2.000000
# 4                 3887                 346            0.000000
# ...                ...                 ...                 ...
# 3581                 0                   0           79.644559
# 3582                13                  53           77.000000
# 3583                 7                  30           48.000000
# 3584                32                  69           42.000000
# 3585                18                  74            0.000000
#
#       Value_of_Output_to_Total_Assets  Value_of_Output_to_Gross_Block
# 0                                0.00                            0.00
# 1                                0.31                            0.24
# 2                               -0.03                           -0.26
# 3                                0.24                            1.90
# 4                                0.01                            0.05
# ...                               ...                             ...
# 3581                             0.60                            7.76
# 3582                             0.29                            1.00
# 3583                             1.42                            3.24
# 3584                             0.36                            0.68
# 3585                             0.42                            0.49
#
# [3581 rows x 34 columns]

# %%
df_new=pd.concat([X,y],axis=1)

# %%
df_new
# Out:
#       Equity_Paid_Up  Net_Working_Capital  Curr_Assets  Other_Income  \
# 0             419.36             -1076.34        40.50          7.60
# 1            1954.93             -1098.88       486.86         46.27
# 2              53.84              4496.25      9097.64          9.55
# 3             157.30             -2612.42      1034.12        223.85
# 4              50.30              1836.23      4685.81          9.82
# ...              ...                  ...          ...           ...
# 3581          501.30                 0.00    444633.50       8996.35
# 3582          296.50              2503.86     11554.45       2008.86
# 3583         2427.95              6376.84     89609.82       5815.66
# 3584         8245.46             11449.79     42353.59       2399.39
# 3585         1998.70            -12145.30     11947.10       5193.00
#
#       Selling_Cost  Rev_earn_in_forex  Rev_exp_in_forex  Capital_exp_in_forex  \
# 0             0.00               0.00              0.00                  0.00
# 1            40.51               6.35            143.42                141.17
# 2            54.83               0.00             86.36                  2.27
# 3             3.34               0.89             28.88                  0.00
# 4             1.97               0.00             15.62                  0.00
# ...            ...                ...               ...                   ...
# 3581        187.47               0.00              0.00                  0.00
# 3582        249.20           14429.18          19525.06                 11.30
# 3583        686.53           16009.99         193979.73                294.88
# 3584         71.22               3.41            962.27               2788.44
# 3585       1555.50            3727.40           3017.20               3722.10
#
#       Book_Value_Unit_Curr  Book_Value_Adj_Unit_Curr  ...  \
# 0                  -167.58                   -167.58  ...
# 1                   -15.18                    -15.18  ...
# 2                    94.14                     94.14  ...
# 3                   -39.64                    -39.64  ...
# 4                  -212.89                   -212.89  ...
# ...                    ...                       ...  ...
# 3581                247.39                    247.39  ...
# 3582                114.87                    114.87  ...
# 3583                279.95                     69.99  ...
# 3584                 99.03                     99.03  ...
# 3585                195.80                    195.80  ...
#
#       Total_Asset_Turnover_Ratio_Latest  Interest_Cover_Ratio_Latest  \
# 0                                  0.00                        -0.20
# 1                                  0.30                        -0.84
# 2                                  0.00                        -2.21
# 3                                  0.00                        -0.16
# 4                                  0.01                        -0.73
# ...                                 ...                          ...
# 3581                               0.00                         0.00
# 3582                               0.30                         3.18
# 3583                               2.62                         8.60
# 3584                               0.39                         4.35
# 3585                               0.38                         2.71
#
#       PBIDTM_perc_Latest  CPM_perc_Latest  Debtors_Vel_Days  \
# 0                   0.00             0.00                 0
# 1                 -10.30           -57.74                29
# 2               -5279.14         -7723.67                97
# 3                  -3.33           -47.70                93
# 4                -295.55           379.79              3887
# ...                  ...              ...               ...
# 3581                0.00             0.00                 0
# 3582               39.92            30.52                13
# 3583                8.09             5.69                 7
# 3584               28.12            19.55                32
# 3585               42.47            25.97                18
#
#       Creditors_Vel_Days  Inventory_Vel_Days  Value_of_Output_to_Total_Assets  \
# 0                      0           45.000000                             0.00
# 1                    101            2.000000                             0.31
# 2                    558            0.000000                            -0.03
# 3                     63            2.000000                             0.24
# 4                    346            0.000000                             0.01
# ...                  ...                 ...                              ...
# 3581                   0           79.644559                             0.60
# 3582                  53           77.000000                             0.29
# 3583                  30           48.000000                             1.42
# 3584                  69           42.000000                             0.36
# 3585                  74            0.000000                             0.42
#
#       Value_of_Output_to_Gross_Block  Default
# 0                               0.00        1
# 1                               0.24        1
# 2                              -0.26        1
# 3                               1.90        1
# 4                               0.05        1
# ...                              ...      ...
# 3581                            7.76        0
# 3582                            1.00        0
# 3583                            3.24        0
# 3584                            0.68        0
# 3585                            0.49        0
#
# [3581 rows x 35 columns]

# %% [markdown]
# ## Split of data based on Default Variable

# %%
sns.countplot(df_new['Default'])

# %%
df_new['Default'].value_counts()
# Out:
# 0    3195
# 1     386
# Name: Default, dtype: int64

# %%
df_new.groupby(df['Default']).sum()
# Out:
#          Equity_Paid_Up  Net_Working_Capital  Curr_Assets  Other_Income  \
# Default
# 0             214218.10           1462147.61   6968115.21     171778.53
# 1              11418.37             10954.66     61538.31       2960.36
#
#          Selling_Cost  Rev_earn_in_forex  Rev_exp_in_forex  \
# Default
# 0            89962.39          464874.78         912428.20
# 1             1662.93            5483.88           6760.43
#
#          Capital_exp_in_forex  Book_Value_Unit_Curr  Book_Value_Adj_Unit_Curr  \
# Default
# 0                    27196.23             586861.65                8085269.63
# 1                      257.07             -23139.27                 -50382.12
#
#          ...  Total_Asset_Turnover_Ratio_Latest  Interest_Cover_Ratio_Latest  \
# Default  ...
# 0        ...                            4034.82                     68139.00
# 1        ...                             399.63                     -9387.15
#
#          PBIDTM_perc_Latest  CPM_perc_Latest  Debtors_Vel_Days  \
# Default
# 0                -124454.16       -463481.66           1982680
# 1                 -58966.72       -637120.30            182255
#
#          Creditors_Vel_Days  Inventory_Vel_Days  \
# Default
# 0                   5105296       250651.944014
# 1                   2260146        34512.445593
#
#          Value_of_Output_to_Total_Assets  Value_of_Output_to_Gross_Block  \
# Default
# 0                                2753.69                       220136.43
# 1                                 182.03                         1773.34
#
#          Default
# Default
# 0              0
# 1            386
#
# [2 rows x 35 columns]

# %% [markdown]
# ## Barplots

# %%
fig, ax = plt.subplots(figsize = (20, 180), nrows = 33, ncols = 2)

for i, col in enumerate(df.columns):
    sns.barplot(x = df['Default'], y = df[col], ax = ax[i//2, i%2],ci=None)
    
plt.tight_layout(pad = 1.1)

# %% [markdown]
# ## Since the data set is very imbalanced. We will apply SMOTE and then we will evaluate all models on both SMOTE as well as NON - SMOTE dataset and compare

# %%
df_smote=df_new.copy()

# %%
print("Before OverSampling the shape of X: {}".format(X.shape))
print("Before OverSampling the shape of y: {}".format(y.shape))

print("Before OverSampling, counts of label '1': {}".format(sum(y==1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y==0)))
# Out:
# Before OverSampling the shape of X: (3581, 34)
# Before OverSampling the shape of y: (3581,)
# Before OverSampling, counts of label '1': 386
# Before OverSampling, counts of label '0': 3195

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=33)

# %%
X_smote,y_smote=sm.fit_sample(X,y.ravel())

# %%
print("After OverSampling the shape of X: {}".format(X_smote.shape))
print("After OverSampling the shape of y: {}".format(y_smote.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_smote==1)))
print("After OverSampling, counts of label '0': {} \n".format(sum(y_smote==0)))
# Out:
# After OverSampling the shape of X: (6390, 34)
# After OverSampling the shape of y: (6390,)
# After OverSampling, counts of label '1': 3195
# After OverSampling, counts of label '0': 3195

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42, stratify = y)

# %%
X_train_smote, X_test_smote, y_train_smote, y_test_smote = train_test_split(
    X_smote, y_smote, test_size = 0.33, random_state = 42, stratify = y_smote)

# %%
X_train_all_scaled = X_train.copy()
X_test_all_scaled=X_test.copy()
y_train_all_scaled=y_train.copy()
y_test_all_scaled=y_test.copy()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_all_scaled=sc.fit_transform(X_train_all_scaled)
X_test_all_scaled=sc.transform(X_test_all_scaled)

# %%
X_train_smote_all_scaled = X_train_smote.copy()
X_test_smote_all_scaled=X_test_smote.copy()
y_train_smote_all_scaled=y_train_smote.copy()
y_test_smote_all_scaled=y_test_smote.copy()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_smote_all_scaled=sc.fit_transform(X_train_smote_all_scaled)
X_test_smote_all_scaled=sc.transform(X_test_smote_all_scaled)

# %% [markdown]
# ## Concatinating X and y, so they can be used with statsmodel library

# %%
df_train = pd.concat([X_train, y_train], axis = 1)
df_test = pd.concat([X_test, y_test], axis = 1)

# %%
df_train
# Out:
#       Equity_Paid_Up  Net_Working_Capital  Curr_Assets  Other_Income  \
# 2218            3.06                40.94        66.67          0.25
# 498             5.10                 0.39        10.15          1.08
# 1154            5.26                 8.87        12.57          0.04
# 1348            6.25                 7.51        12.64          0.02
# 3540          289.37              -892.08      3862.90        582.42
# ...              ...                  ...          ...           ...
# 463             5.25                74.68       117.52          0.12
# 143            42.56                35.49       174.83          5.29
# 1522           15.50                 6.56         7.30          0.00
# 14             67.27              -197.77       131.31          8.45
# 3139           17.47               501.78      1390.93         62.52
#
#       Selling_Cost  Rev_earn_in_forex  Rev_exp_in_forex  Capital_exp_in_forex  \
# 2218          7.65              23.25             23.34                  4.82
# 498           0.01               0.00              0.10                  0.00
# 1154          0.00               0.00              4.95                  0.00
# 1348          2.14               0.00              0.00                  0.00
# 3540        576.87            9443.51            830.61                 25.47
# ...            ...                ...               ...                   ...
# 463           0.21               0.00              0.00                  0.00
# 143          23.35             269.59            123.31                  0.65
# 1522          0.12               0.45              0.01                  0.00
# 14            0.21               0.00              0.34                  0.00
# 3139         18.91              46.99            258.08                  2.03
#
#       Book_Value_Unit_Curr  Book_Value_Adj_Unit_Curr  ...  \
# 2218                132.56                    132.56  ...
# 498                   1.24                      1.24  ...
# 1154                 12.07                     12.07  ...
# 1348                 13.20                     13.20  ...
# 3540                369.50                    369.50  ...
# ...                    ...                       ...  ...
# 463                   0.71                      0.71  ...
# 143                  -8.40                     -8.40  ...
# 1522                  0.80                      0.80  ...
# 14                 -119.54                   -119.54  ...
# 3139                 48.53                     48.53  ...
#
#       Total_Asset_Turnover_Ratio_Latest  Interest_Cover_Ratio_Latest  \
# 2218                               1.02                         1.13
# 498                                2.81                         2.24
# 1154                               3.54                         1.29
# 1348                               0.42                         4.60
# 3540                               1.50                      3812.16
# ...                                 ...                          ...
# 463                                0.63                         1.60
# 143                                5.23                        -0.44
# 1522                               0.13                         0.00
# 14                                 0.00                        -1.40
# 3139                               0.67                         0.10
#
#       PBIDTM_perc_Latest  CPM_perc_Latest  Debtors_Vel_Days  \
# 2218               12.62             9.21               119
# 498                 3.60             2.28              2023
# 1154                2.84             0.82                53
# 1348               44.10            24.96               422
# 3540               24.45            17.91                12
# ...                  ...              ...               ...
# 463                12.02             5.48               481
# 143                -1.26            -5.11                41
# 1522                8.12             8.97               601
# 14                -78.94          -138.85                34
# 3139                9.61            -1.92                67
#
#       Creditors_Vel_Days  Inventory_Vel_Days  Value_of_Output_to_Total_Assets  \
# 2218                  37               108.0                             0.85
# 498                 1179                 0.0                             1.13
# 1154                  19                 8.0                             3.28
# 1348                 642                47.0                             0.27
# 3540                  40                16.0                             1.22
# ...                  ...                 ...                              ...
# 463                  508                 0.0                             0.47
# 143                   30                58.0                             1.81
# 1522                  12               629.0                             0.15
# 14                   160                81.0                             0.52
# 3139                  87               112.0                             0.48
#
#       Value_of_Output_to_Gross_Block  Default
# 2218                            0.70        0
# 498                             2.55        0
# 1154                           18.12        0
# 1348                            4.03        0
# 3540                            5.07        0
# ...                              ...      ...
# 463                             2.44        0
# 143                             1.87        1
# 1522                            0.08        0
# 14                              0.24        1
# 3139                            0.62        0
#
# [2399 rows x 35 columns]

# %%
df_test
# Out:
#       Equity_Paid_Up  Net_Working_Capital  Curr_Assets  Other_Income  \
# 1682           11.75                 3.01         3.38          0.62
# 3260           25.98               478.87       855.19         28.00
# 2156            9.34                 7.40        59.65          1.48
# 3295            7.35               424.45      1960.66         42.31
# 1311            5.05                 2.82         4.30          0.23
# ...              ...                  ...          ...           ...
# 2539            8.90               112.20       130.61          0.30
# 451             0.35                 0.02         0.06          0.00
# 1058            3.69                 2.52         2.72          0.23
# 2378            5.29                49.48       153.78          3.82
# 762             0.27                 0.09         0.14          0.00
#
#       Selling_Cost  Rev_earn_in_forex  Rev_exp_in_forex  Capital_exp_in_forex  \
# 1682          0.15               0.00              0.00                  0.00
# 3260         83.82            1032.47            225.05                  0.14
# 2156          0.00               0.00              0.00                  0.00
# 3295        267.03            1166.70            321.98                  3.49
# 1311          0.03              10.55              0.05                  0.00
# ...            ...                ...               ...                   ...
# 2539         17.62             279.55              7.73                  0.00
# 451           0.01               0.00              0.00                  0.00
# 1058          0.03               1.41              0.01                  0.00
# 2378         53.80              30.19              6.28                  0.00
# 762           0.01               0.00              0.00                  0.00
#
#       Book_Value_Unit_Curr  Book_Value_Adj_Unit_Curr  ...  \
# 1682                 13.30                     13.30  ...
# 3260                332.14                    332.14  ...
# 2156                 34.56                     34.56  ...
# 3295               1046.88                   1046.88  ...
# 1311                 16.15                     16.15  ...
# ...                    ...                       ...  ...
# 2539                 91.86                     73.49  ...
# 451                   0.94                      0.94  ...
# 1058                 10.67                     10.67  ...
# 2378                111.42                    111.42  ...
# 762                  10.21                     10.21  ...
#
#       Total_Asset_Turnover_Ratio_Latest  Interest_Cover_Ratio_Latest  \
# 1682                               0.24                         1.53
# 3260                               0.82                         5.28
# 2156                               1.55                         2.47
# 3295                               2.08                         7.84
# 1311                               1.31                         3.74
# ...                                 ...                          ...
# 2539                               3.66                         2.09
# 451                                0.24                         0.00
# 1058                               0.00                         1.00
# 2378                               5.18                        16.93
# 762                                0.11                         0.00
#
#       PBIDTM_perc_Latest  CPM_perc_Latest  Debtors_Vel_Days  \
# 1682               22.67             9.96                17
# 3260               33.27            21.13                15
# 2156               10.54             5.93                39
# 3295               10.53             7.27                94
# 1311                8.52             5.51                98
# ...                  ...              ...               ...
# 2539                5.40             2.94                44
# 451                 0.00             0.00                 0
# 1058                0.00             0.00                29
# 2378               12.53             8.10                28
# 762                 0.00             0.00               365
#
#       Creditors_Vel_Days  Inventory_Vel_Days  Value_of_Output_to_Total_Assets  \
# 1682                  26                77.0                             0.24
# 3260                  58               150.0                             0.68
# 2156                 116                99.0                             1.18
# 3295                 110                58.0                             1.04
# 1311                   5                 0.0                             1.20
# ...                  ...                 ...                              ...
# 2539                   6                34.0                             3.18
# 451                    0                 0.0                             0.20
# 1058                   3                27.0                             0.00
# 2378                  34                71.0                             2.71
# 762                 1460                 0.0                             0.00
#
#       Value_of_Output_to_Gross_Block  Default
# 1682                            0.23        0
# 3260                            1.16        0
# 2156                            2.39        0
# 3295                            3.63        0
# 1311                            1.56        0
# ...                              ...      ...
# 2539                            4.76        0
# 451                             0.00        0
# 1058                            0.00        0
# 2378                           10.72        0
# 762                             0.00        0
#
# [1182 rows x 35 columns]

# %%
df_train_smote = pd.concat([X_train_smote, pd.DataFrame(y_train_smote,index=X_train_smote.index)], axis = 1)
df_test_smote = pd.concat([X_test_smote, pd.DataFrame(y_test_smote,index=X_test_smote.index)], axis = 1)

# %%
df_train_smote.columns=[                   'Equity_Paid_Up',
                     'Net_Working_Capital',
                             'Curr_Assets',
                            'Other_Income',
                            'Selling_Cost',
                       'Rev_earn_in_forex',
                        'Rev_exp_in_forex',
                    'Capital_exp_in_forex',
                    'Book_Value_Unit_Curr',
                'Book_Value_Adj_Unit_Curr',
                   'Market_Capitalisation',
               'CEPS_annualised_Unit_Curr',
                      'Cash_Flow_From_Opr',
                      'Cash_Flow_From_Inv',
               'ROG_Capital_Employed_perc',
                    'ROG_Gross_Block_perc',
                      'ROG_Net_Sales_perc',
                   'ROG_Cost_of_Prod_perc',
                            'ROG_PAT_perc',
              'ROG_Rev_earn_in_forex_perc',
               'ROG_Rev_exp_in_forex_perc',
          'ROG_Market_Capitalisation_perc',
                       'Curr_Ratio_Latest',
                  'Inventory_Ratio_Latest',
                    'Debtors_Ratio_Latest',
       'Total_Asset_Turnover_Ratio_Latest',
             'Interest_Cover_Ratio_Latest',
                      'PBIDTM_perc_Latest',
                         'CPM_perc_Latest',
                        'Debtors_Vel_Days',
                      'Creditors_Vel_Days',
                      'Inventory_Vel_Days',
         'Value_of_Output_to_Total_Assets',
          'Value_of_Output_to_Gross_Block',
                        'Default']
df_train_smote
# Out:
#       Equity_Paid_Up  Net_Working_Capital  Curr_Assets  Other_Income  \
# 4223        7.347672             7.020814    15.989639      5.816834
# 3493       58.010000          3321.460000  5247.240000    123.720000
# 2844       11.560000           135.650000   267.950000      3.250000
# 4221        8.509298             0.610611     1.269695     10.223334
# 5583        3.960926           -12.222521     1.994483      0.000000
# ...              ...                  ...          ...           ...
# 2037        5.590000            19.890000    28.630000      2.420000
# 1231        0.500000             5.660000    16.670000      0.020000
# 4528       38.063388            70.952532   109.997387     11.169226
# 3629        3.371029            -0.013994     0.029000      0.084003
# 1428        9.660000            30.590000    30.810000      0.000000
#
#       Selling_Cost  Rev_earn_in_forex  Rev_exp_in_forex  Capital_exp_in_forex  \
# 4223      0.560601           6.752390          0.442210              0.000000
# 3493    376.330000        2110.860000       2560.660000             72.470000
# 2844     11.670000          95.910000        146.260000              2.890000
# 4221      0.010000           0.004309          0.008618              0.000000
# 5583      0.001584           0.000000          0.000000              0.000000
# ...            ...                ...               ...                   ...
# 2037      1.310000           0.000000          0.000000              0.000000
# 1231      1.000000           0.000000          0.000000              0.000000
# 4528      2.001923          67.912435          5.000147              1.534478
# 3629      0.001999           0.000000          0.000000              0.000000
# 1428      0.010000           0.000000          0.000000              0.000000
#
#       Book_Value_Unit_Curr  Book_Value_Adj_Unit_Curr  ...  \
# 4223             -2.623808                 -2.623808  ...
# 3493            194.310000                194.310000  ...
# 2844            161.570000                 80.790000  ...
# 4221             -0.634595                 -0.634595  ...
# 5583            -30.534538                -30.534538  ...
# ...                    ...                       ...  ...
# 2037             50.670000                 50.670000  ...
# 1231             93.680000                 31.230000  ...
# 4528            -23.234465                -23.234465  ...
# 3629             -0.698709                 -0.698709  ...
# 1428              1.070000                  1.070000  ...
#
#       Total_Asset_Turnover_Ratio_Latest  Interest_Cover_Ratio_Latest  \
# 4223                           1.204066                     0.047095
# 3493                           0.580000                     2.240000
# 2844                           4.350000                     4.550000
# 4221                           0.453878                    -1.723518
# 5583                           0.000000                     0.000000
# ...                                 ...                          ...
# 2037                           0.900000                     3.150000
# 1231                           4.190000                     3.970000
# 4528                           1.040901                   -19.118507
# 3629                           0.000000                     0.000000
# 1428                           0.120000                     1.090000
#
#       PBIDTM_perc_Latest  CPM_perc_Latest  Debtors_Vel_Days  \
# 4223          -17.784282       -73.110859                66
# 3493           18.370000         9.220000                75
# 2844            5.480000         3.540000                58
# 4221            3.425494         3.425494                14
# 5583            0.000000         0.000000                 0
# ...                  ...              ...               ...
# 2037           14.060000         8.670000                41
# 1231            7.880000         4.490000                58
# 4528          -11.458420       -13.064260                95
# 3629            0.000000         0.000000                 0
# 1428           95.200000         5.760000                 0
#
#       Creditors_Vel_Days  Inventory_Vel_Days  Value_of_Output_to_Total_Assets  \
# 4223                  37          112.552142                         0.973436
# 3493                  31          124.000000                         0.580000
# 2844                  55           39.000000                         2.120000
# 4221                 398            0.000000                         0.359677
# 5583                   0            0.000000                         0.000000
# ...                  ...                 ...                              ...
# 2037                  38           52.000000                         0.950000
# 1231                   5            0.000000                         4.020000
# 4528                  61           81.695859                         0.841460
# 3629                  12            0.000000                         0.000000
# 1428                  57            0.000000                         0.190000
#
#       Value_of_Output_to_Gross_Block  Default
# 4223                        0.745392        1
# 3493                        1.040000        0
# 2844                        3.420000        0
# 4221                        0.000000        1
# 5583                        0.000000        1
# ...                              ...      ...
# 2037                        2.530000        0
# 1231                       12.010000        0
# 4528                        4.561193        1
# 3629                        0.000000        1
# 1428                       86.420000        0
#
# [4281 rows x 35 columns]

# %%
df_test_smote.columns=['Equity_Paid_Up',
                     'Net_Working_Capital',
                             'Curr_Assets',
                            'Other_Income',
                            'Selling_Cost',
                       'Rev_earn_in_forex',
                        'Rev_exp_in_forex',
                    'Capital_exp_in_forex',
                    'Book_Value_Unit_Curr',
                'Book_Value_Adj_Unit_Curr',
                   'Market_Capitalisation',
               'CEPS_annualised_Unit_Curr',
                      'Cash_Flow_From_Opr',
                      'Cash_Flow_From_Inv',
               'ROG_Capital_Employed_perc',
                    'ROG_Gross_Block_perc',
                      'ROG_Net_Sales_perc',
                   'ROG_Cost_of_Prod_perc',
                            'ROG_PAT_perc',
              'ROG_Rev_earn_in_forex_perc',
               'ROG_Rev_exp_in_forex_perc',
          'ROG_Market_Capitalisation_perc',
                       'Curr_Ratio_Latest',
                  'Inventory_Ratio_Latest',
                    'Debtors_Ratio_Latest',
       'Total_Asset_Turnover_Ratio_Latest',
             'Interest_Cover_Ratio_Latest',
                      'PBIDTM_perc_Latest',
                         'CPM_perc_Latest',
                        'Debtors_Vel_Days',
                      'Creditors_Vel_Days',
                      'Inventory_Vel_Days',
         'Value_of_Output_to_Total_Assets',
          'Value_of_Output_to_Gross_Block',
                       'Default']

df_test_smote
# Out:
#       Equity_Paid_Up  Net_Working_Capital  Curr_Assets  Other_Income  \
# 2835       22.380000            78.410000   103.390000      8.640000
# 397         3.480000             1.590000     1.590000      0.000000
# 6079       17.176523           -10.459328    21.625558      6.387596
# 1238        3.360000             7.660000     8.350000      0.450000
# 5033        8.221044            -0.404253     0.508410      0.248232
# ...              ...                  ...          ...           ...
# 1262       15.910000             5.100000    15.710000      0.070000
# 5567        5.449801             0.012240     0.082071      0.000317
# 705         3.000000             1.770000     1.890000      0.000000
# 2666        5.240000            53.720000    74.820000      1.640000
# 5008        5.119697            -3.756400     0.268286      0.000000
#
#       Selling_Cost  Rev_earn_in_forex  Rev_exp_in_forex  Capital_exp_in_forex  \
# 2835     21.150000         127.530000          8.420000                  0.29
# 397       0.000000           0.000000          0.000000                  0.00
# 6079      0.541956           0.068453          0.000000                  0.00
# 1238      0.260000           2.030000          0.000000                  0.00
# 5033      0.000000           0.000000          0.000000                  0.00
# ...            ...                ...               ...                   ...
# 1262      0.020000           0.000000          0.000000                  0.00
# 5567      0.000000           0.000000          0.000317                  0.00
# 705       0.000000           0.000000          0.000000                  0.00
# 2666      2.580000          72.720000          2.170000                  0.45
# 5008      0.002128           0.000000          0.000000                  0.00
#
#       Book_Value_Unit_Curr  Book_Value_Adj_Unit_Curr  ...  \
# 2835             78.560000                 78.560000  ...
# 397               4.630000                  4.630000  ...
# 6079            -23.919190                -23.919190  ...
# 1238             22.110000                 22.110000  ...
# 5033            -13.115452                -13.115452  ...
# ...                    ...                       ...  ...
# 1262              6.280000                  6.280000  ...
# 5567             -1.392903                 -1.366660  ...
# 705              10.020000                 10.020000  ...
# 2666            217.570000                217.570000  ...
# 5008             -4.804989                 -4.804989  ...
#
#       Total_Asset_Turnover_Ratio_Latest  Interest_Cover_Ratio_Latest  \
# 2835                           0.840000                    21.030000
# 397                            0.000000                     0.000000
# 6079                           0.000000                    -0.162576
# 1238                           0.730000                    -1.090000
# 5033                           0.000000                   -47.389800
# ...                                 ...                          ...
# 1262                           0.420000                   -70.330000
# 5567                           0.007294                     0.013320
# 705                            0.050000                     0.000000
# 2666                           0.480000                     3.210000
# 5008                           0.000000                     0.000000
#
#       PBIDTM_perc_Latest  CPM_perc_Latest  Debtors_Vel_Days  \
# 2835           16.250000        11.690000                72
# 397             0.000000         0.000000                 0
# 6079            2.045041        -5.305127                27
# 1238           -3.100000        -9.950000                29
# 5033            0.000000         0.000000                 0
# ...                  ...              ...               ...
# 1262           -0.450000         4.160000               196
# 5567            0.157302         0.256804                 0
# 705            38.890000        77.780000                 0
# 2666           16.160000        11.140000               112
# 5008            0.000000         0.000000                 0
#
#       Creditors_Vel_Days  Inventory_Vel_Days  Value_of_Output_to_Total_Assets  \
# 2835                  24           89.000000                         0.780000
# 397                    0            0.000000                         0.000000
# 6079                  51           72.731581                         0.838552
# 1238                  10          254.000000                         0.650000
# 5033                 659          750.761849                         0.000000
# ...                  ...                 ...                              ...
# 1262                 201          202.000000                         0.240000
# 5567                   0            0.000000                         0.002537
# 705                    0            0.000000                         0.050000
# 2666                  45          149.000000                         0.450000
# 5008                   0            0.000000                         0.000000
#
#       Value_of_Output_to_Gross_Block  Default
# 2835                        1.480000        0
# 397                         0.000000        0
# 6079                        0.367936        1
# 1238                        0.880000        0
# 5033                        0.000000        1
# ...                              ...      ...
# 1262                        0.280000        0
# 5567                        0.001982        1
# 705                         0.000000        0
# 2666                        1.110000        0
# 5008                        0.000000        1
#
# [2109 rows x 35 columns]

# %%
col=[]
for i in df_train.columns[:-1]:
    col.append(i)

# %%
col
# Out:
# ['Equity_Paid_Up',
#  'Net_Working_Capital',
#  'Curr_Assets',
#  'Other_Income',
#  'Selling_Cost',
#  'Rev_earn_in_forex',
#  'Rev_exp_in_forex',
#  'Capital_exp_in_forex',
#  'Book_Value_Unit_Curr',
#  'Book_Value_Adj_Unit_Curr',
#  'Market_Capitalisation',
#  'CEPS_annualised_Unit_Curr',
#  'Cash_Flow_From_Opr',
#  'Cash_Flow_From_Inv',
#  'ROG_Capital_Employed_perc',
#  'ROG_Gross_Block_perc',
#  'ROG_Net_Sales_perc',
#  'ROG_Cost_of_Prod_perc',
#  'ROG_PAT_perc',
#  'ROG_Rev_earn_in_forex_perc',
#  'ROG_Rev_exp_in_forex_perc',
#  'ROG_Market_Capitalisation_perc',
#  'Curr_Ratio_Latest',
#  'Inventory_Ratio_Latest',
#  'Debtors_Ratio_Latest',
#  'Total_Asset_Turnover_Ratio_Latest',
#  'Interest_Cover_Ratio_Latest',
#  'PBIDTM_perc_Latest',
#  'CPM_perc_Latest',
#  'Debtors_Vel_Days',
#  'Creditors_Vel_Days',
#  'Inventory_Vel_Days',
#  'Value_of_Output_to_Total_Assets',
#  'Value_of_Output_to_Gross_Block']

# %% [markdown]
# # Model Building using Logistic Regression for 'Probability at default'

# %% [markdown]
# ## The equation of the Logistic Regression by which we predict the corresponding probabilities and then go on predict a discrete target variable is
# # y = $\frac{1}{1 + {e^{-z}}}$
#
# ### Note: z  = $\beta_0$ +${\sum_{i=1}^{n}(\beta_i  X_1)}$

# %% [markdown]
# ### Statsmodels Logit Modeling with backward elimination.
# #### After each model is built, the variable that has a p-value of >0.05 will be dropped as their coefficients are unreliable.

# %%
def metrics_eval(df,model,count,train_test,optimal_threshold_ip):
    y_prob_pred = model.predict(df)
    highest_pvalue_col_name=model.pvalues.sort_values(ascending = False).head(1).index.to_list()[0]
    highest_pvalue=model.pvalues.sort_values(ascending = False).head(1).values[0]
    if train_test=='train':
        fpr, tpr, thresholds = roc_curve(df['Default'], y_prob_pred)
        auc = roc_auc_score(df['Default'], y_prob_pred)
        optimal_idx = np.argmax(tpr - fpr)
        optimal_threshold = thresholds[optimal_idx]
    elif train_test=='test':
        auc = roc_auc_score(df['Default'], y_prob_pred)
        optimal_threshold=optimal_threshold_ip      
    y_class_pred=[]
    for i in range(0,len(y_prob_pred)):
        if np.array(y_prob_pred)[i] > optimal_threshold:
            a=1
        else:
            a=0
        y_class_pred.append(a)
    dict_metrics={'ModelType':'Logit',
        'Model_Name':'Model_'+str(count),
          'Accuracy':accuracy_score(df['Default'], y_class_pred),
          'F1 Score':f1_score(df['Default'], y_class_pred),
          'Recall':recall_score(df['Default'], y_class_pred),
          'Precision':precision_score(df['Default'], y_class_pred),
                  'AUC':auc,
                  'Optimal_Thresh':optimal_threshold,
                 'Dropped_Column':highest_pvalue_col_name,
                 'Dropped_col_pvalue':highest_pvalue}
    return dict_metrics,optimal_threshold

# %%
def logit_model_eval(df_train,df_test,num_of_models):
    df_metrics_test=pd.DataFrame(columns=['ModelType','Model_Name','Accuracy','F1 Score','Recall','Precision',
                                          'AUC',
                                          'Optimal_Thresh',
                                          'Dropped_Column',
                                         'Dropped_col_pvalue'])
    df_metrics_train=pd.DataFrame(columns=['ModelType','Model_Name','Accuracy','F1 Score','Recall','Precision',
                                           'Optimal_Thresh','AUC',
                                           'Dropped_Column','Dropped_col_pvalue'])
    model_list=[]
    col=[]
    for i in df_train.columns[:-1]:
        col.append(i)
    count=1
    for i in np.arange(1,num_of_models):
        text=""
        j=0
        for k in col:
            if j==0:
                j=j+1
                text='Default ~ '
            if j==1:
                j=j+1
                text=text+k
            else:
                text=text+" + "+k
        model = SM.logit(formula = text, data = df_train).fit(maxiter = 10000, method = 'bfgs',disp=0)
        highest_pvalue=model.pvalues.sort_values(ascending = False).head(1).values[0]
        highest_pvalue_col_name=model.pvalues.sort_values(ascending = False).head(1).index.to_list()[0]

        if highest_pvalue > 0.05:
            col=list(filter(lambda x: x != highest_pvalue_col_name,col))
            #-------------------------------validation Train Set -----------------------------------
            dict_metrics_train,optimal_threshold_op=metrics_eval(df_train,model,count,train_test="train",
                                                              optimal_threshold_ip=None)
            df_metrics_train=df_metrics_train.append(dict_metrics_train,ignore_index=True)
            #print("train model number"+str(count))
            #-------------------------------validation Test Set -----------------------------------
            dict_metrics_test,optimal_threshold_op=metrics_eval(df_test,model,count,train_test="test",
                                           optimal_threshold_ip=optimal_threshold_op)
            df_metrics_test=df_metrics_test.append(dict_metrics_test,ignore_index=True)
            #print("test model number"+str(count))
            model_list.append(model)
            count=count+1
            continue
        else:
            #-------------------------------validation Train Set -----------------------------------
            dict_metrics_train,optimal_threshold_op=metrics_eval(df_train,model,count,train_test="train",
                                                              optimal_threshold_ip=None)
            df_metrics_train=df_metrics_train.append(dict_metrics_train,ignore_index=True)
            #-------------------------------validation Test Set -----------------------------------
            dict_metrics_test,optimal_threshold_op=metrics_eval(df_test,model,count,train_test="test",
                                           optimal_threshold_ip=optimal_threshold_op)
            df_metrics_test=df_metrics_test.append(dict_metrics_test,ignore_index=True)
            model_list.append(model)
            count=count+1
            break
    return model_list,df_metrics_train,df_metrics_test

# %%
model_list,df_metrics_train_logit,df_metrics_test_logit=logit_model_eval(df_train,df_test,num_of_models=300)

# %%
df_metrics_train_logit.sort_values(by='Accuracy',ascending=False)
# Out:
#    ModelType Model_Name  Accuracy  F1 Score    Recall  Precision  \
# 29     Logit   Model_30  0.958316  0.822695  0.895753   0.760656
# 30     Logit   Model_31  0.956232  0.816112  0.899614   0.746795
# 10     Logit   Model_11  0.952897  0.806838  0.911197   0.723926
# 9      Logit   Model_10  0.952480  0.805461  0.911197   0.721713
# 14     Logit   Model_15  0.952480  0.806780  0.918919   0.719033
# 11     Logit   Model_12  0.952480  0.805461  0.911197   0.721713
# 13     Logit   Model_14  0.952063  0.804754  0.915058   0.718182
# 15     Logit   Model_16  0.952063  0.804754  0.915058   0.718182
# 12     Logit   Model_13  0.951647  0.802721  0.911197   0.717325
# 16     Logit   Model_17  0.950396  0.799325  0.915058   0.709581
# 23     Logit   Model_24  0.949145  0.794613  0.911197   0.704478
# 24     Logit   Model_25  0.948729  0.793277  0.911197   0.702381
# 22     Logit   Model_23  0.948729  0.793277  0.911197   0.702381
# 21     Logit   Model_22  0.948729  0.793277  0.911197   0.702381
# 17     Logit   Model_18  0.948312  0.793333  0.918919   0.697947
# 25     Logit   Model_26  0.947895  0.790620  0.911197   0.698225
# 20     Logit   Model_21  0.947478  0.790000  0.915058   0.695015
# 19     Logit   Model_20  0.946228  0.786070  0.915058   0.688953
# 18     Logit   Model_19  0.946228  0.786777  0.918919   0.687861
# 27     Logit   Model_28  0.945811  0.784053  0.911197   0.688047
# 26     Logit   Model_27  0.943310  0.777049  0.915058   0.675214
# 28     Logit   Model_29  0.942893  0.775777  0.915058   0.673295
# 7      Logit    Model_8  0.939558  0.768740  0.930502   0.654891
# 3      Logit    Model_4  0.939558  0.768740  0.930502   0.654891
# 5      Logit    Model_6  0.939558  0.768740  0.930502   0.654891
# 6      Logit    Model_7  0.939558  0.768740  0.930502   0.654891
# 2      Logit    Model_3  0.939141  0.767516  0.930502   0.653117
# 1      Logit    Model_2  0.939141  0.767516  0.930502   0.653117
# 4      Logit    Model_5  0.939141  0.767516  0.930502   0.653117
# 0      Logit    Model_1  0.938724  0.766296  0.930502   0.651351
# 8      Logit    Model_9  0.937891  0.763867  0.930502   0.647849
#
#     Optimal_Thresh       AUC                     Dropped_Column  \
# 29        0.247407  0.975275             Inventory_Ratio_Latest
# 30        0.241328  0.975041                          Intercept
# 10        0.219286  0.976901           Book_Value_Adj_Unit_Curr
# 9         0.217851  0.976899                   Rev_exp_in_forex
# 14        0.217665  0.976802               Debtors_Ratio_Latest
# 11        0.218126  0.976877     ROG_Market_Capitalisation_perc
# 13        0.216755  0.976769  Total_Asset_Turnover_Ratio_Latest
# 15        0.217733  0.976758                 ROG_Net_Sales_perc
# 12        0.218326  0.976848          ROG_Capital_Employed_perc
# 16        0.216078  0.976749                   Debtors_Vel_Days
# 23        0.208356  0.976212                        Curr_Assets
# 24        0.208039  0.976230                    CPM_perc_Latest
# 22        0.208713  0.976327                 Cash_Flow_From_Opr
# 21        0.208683  0.976376                  Rev_earn_in_forex
# 17        0.209920  0.976681    Value_of_Output_to_Total_Assets
# 25        0.207759  0.976201              Market_Capitalisation
# 20        0.203360  0.976374                       Other_Income
# 19        0.202278  0.976441                 Creditors_Vel_Days
# 18        0.204037  0.976693         ROG_Rev_earn_in_forex_perc
# 27        0.201248  0.975759               ROG_Gross_Block_perc
# 26        0.196395  0.975728                Net_Working_Capital
# 28        0.197805  0.975663                       ROG_PAT_perc
# 7         0.182621  0.976884                 Inventory_Vel_Days
# 3         0.181397  0.976928                     Equity_Paid_Up
# 5         0.181308  0.976933          ROG_Rev_exp_in_forex_perc
# 6         0.180946  0.976915              ROG_Cost_of_Prod_perc
# 2         0.181410  0.976933               Capital_exp_in_forex
# 1         0.181491  0.976944                 PBIDTM_perc_Latest
# 4         0.181535  0.976915                 Cash_Flow_From_Inv
# 0         0.181489  0.976935                       Selling_Cost
# 8         0.178952  0.976922     Value_of_Output_to_Gross_Block
#
#     Dropped_col_pvalue
# 29            0.094421
# 30            0.008277
# 10            0.596393
# 9             0.627171
# 14            0.495727
# 11            0.594895
# 13            0.525161
# 15            0.468116
# 12            0.544502
# 16            0.469351
# 23            0.447201
# 24            0.322666
# 22            0.712346
# 21            0.855882
# 17            0.390308
# 25            0.261061
# 20            0.301154
# 19            0.318407
# 18            0.319251
# 27            0.160827
# 26            0.432204
# 28            0.170844
# 7             0.763023
# 3             0.875767
# 5             0.821508
# 6             0.800080
# 2             0.877015
# 1             0.878034
# 4             0.834561
# 0             0.993767
# 8             0.696161

# %%
df_metrics_test_logit.sort_values(by='Accuracy',ascending=False)
# Out:
#    ModelType Model_Name  Accuracy  F1 Score    Recall  Precision       AUC  \
# 30     Logit   Model_31  0.952623  0.802817  0.897638   0.726115  0.956256
# 29     Logit   Model_30  0.952623  0.802817  0.897638   0.726115  0.956629
# 25     Logit   Model_26  0.939932  0.764120  0.905512   0.660920  0.949013
# 22     Logit   Model_23  0.939086  0.763158  0.913386   0.655367  0.948502
# 21     Logit   Model_22  0.939086  0.763158  0.913386   0.655367  0.948233
# 24     Logit   Model_25  0.938240  0.759076  0.905512   0.653409  0.948614
# 23     Logit   Model_24  0.938240  0.759076  0.905512   0.653409  0.948800
# 27     Logit   Model_28  0.937394  0.754967  0.897638   0.651429  0.947326
# 16     Logit   Model_17  0.934010  0.743421  0.889764   0.638418  0.944031
# 28     Logit   Model_29  0.934010  0.748387  0.913386   0.633880  0.955756
# 11     Logit   Model_12  0.933164  0.742671  0.897638   0.633333  0.945419
# 26     Logit   Model_27  0.932318  0.741935  0.905512   0.628415  0.948065
# 15     Logit   Model_16  0.932318  0.738562  0.889764   0.631285  0.944233
# 9      Logit   Model_10  0.932318  0.738562  0.889764   0.631285  0.945330
# 10     Logit   Model_11  0.932318  0.738562  0.889764   0.631285  0.945263
# 12     Logit   Model_13  0.931472  0.736156  0.889764   0.627778  0.945486
# 17     Logit   Model_18  0.931472  0.737864  0.897638   0.626374  0.943464
# 14     Logit   Model_15  0.930626  0.733766  0.889764   0.624309  0.944292
# 13     Logit   Model_14  0.930626  0.733766  0.889764   0.624309  0.944285
# 19     Logit   Model_20  0.928934  0.735849  0.921260   0.612565  0.944374
# 20     Logit   Model_21  0.928934  0.734177  0.913386   0.613757  0.941896
# 18     Logit   Model_19  0.928934  0.732484  0.905512   0.614973  0.943315
# 7      Logit    Model_8  0.920474  0.709877  0.905512   0.583756  0.945576
# 1      Logit    Model_2  0.919628  0.707692  0.905512   0.580808  0.945076
# 6      Logit    Model_7  0.919628  0.707692  0.905512   0.580808  0.945643
# 5      Logit    Model_6  0.919628  0.707692  0.905512   0.580808  0.945643
# 3      Logit    Model_4  0.919628  0.707692  0.905512   0.580808  0.945688
# 2      Logit    Model_3  0.919628  0.707692  0.905512   0.580808  0.945300
# 0      Logit    Model_1  0.919628  0.707692  0.905512   0.580808  0.945054
# 8      Logit    Model_9  0.918782  0.707317  0.913386   0.577114  0.945367
# 4      Logit    Model_5  0.918782  0.703704  0.897638   0.578680  0.945695
#
#     Optimal_Thresh                     Dropped_Column  Dropped_col_pvalue
# 30        0.241328                          Intercept            0.008277
# 29        0.247407             Inventory_Ratio_Latest            0.094421
# 25        0.207759              Market_Capitalisation            0.261061
# 22        0.208713                 Cash_Flow_From_Opr            0.712346
# 21        0.208683                  Rev_earn_in_forex            0.855882
# 24        0.208039                    CPM_perc_Latest            0.322666
# 23        0.208356                        Curr_Assets            0.447201
# 27        0.201248               ROG_Gross_Block_perc            0.160827
# 16        0.216078                   Debtors_Vel_Days            0.469351
# 28        0.197805                       ROG_PAT_perc            0.170844
# 11        0.218126     ROG_Market_Capitalisation_perc            0.594895
# 26        0.196395                Net_Working_Capital            0.432204
# 15        0.217733                 ROG_Net_Sales_perc            0.468116
# 9         0.217851                   Rev_exp_in_forex            0.627171
# 10        0.219286           Book_Value_Adj_Unit_Curr            0.596393
# 12        0.218326          ROG_Capital_Employed_perc            0.544502
# 17        0.209920    Value_of_Output_to_Total_Assets            0.390308
# 14        0.217665               Debtors_Ratio_Latest            0.495727
# 13        0.216755  Total_Asset_Turnover_Ratio_Latest            0.525161
# 19        0.202278                 Creditors_Vel_Days            0.318407
# 20        0.203360                       Other_Income            0.301154
# 18        0.204037         ROG_Rev_earn_in_forex_perc            0.319251
# 7         0.182621                 Inventory_Vel_Days            0.763023
# 1         0.181491                 PBIDTM_perc_Latest            0.878034
# 6         0.180946              ROG_Cost_of_Prod_perc            0.800080
# 5         0.181308          ROG_Rev_exp_in_forex_perc            0.821508
# 3         0.181397                     Equity_Paid_Up            0.875767
# 2         0.181410               Capital_exp_in_forex            0.877015
# 0         0.181489                       Selling_Cost            0.993767
# 8         0.178952     Value_of_Output_to_Gross_Block            0.696161
# 4         0.181535                 Cash_Flow_From_Inv            0.834561

# %% [markdown]
# ## Finding the best model

# %%
model_list
# Out:
# [<statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182a0b4548>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x21827344f48>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x21827678848>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x21827708388>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182f121ac8>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x218276bd188>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182722bb88>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182aa7dc48>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x218296c1a08>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182f2796c8>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182c777f88>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x21829d131c8>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182a843408>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182a843fc8>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182a3e3208>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x21829a52d88>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182c845308>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182c70cb48>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x21829764188>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182a8ada48>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182a789708>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182f51ce88>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182ce84308>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x218296d0448>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182a91e4c8>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182c42bec8>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182c8524c8>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182e11fec8>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182f9ea4c8>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x21827127a08>,
#  <statsmodels.discrete.discrete_model.BinaryResultsWrapper at 0x2182add95c8>]

# %%
best_model=model_list[df_metrics_test_logit.sort_values(by='Accuracy',ascending=False).index[0]]
best_model

# %%
print(best_model.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Default   No. Observations:                 2399
# Model:                          Logit   Df Residuals:                     2394
# Method:                           MLE   Df Model:                            4
# Date:                Wed, 24 Feb 2021   Pseudo R-squ.:                  0.6358
# Time:                        20:20:36   Log-Likelihood:                -299.04
# converged:                       True   LL-Null:                       -821.02
# Covariance Type:            nonrobust   LLR p-value:                1.067e-224
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.3898      0.148     -2.641      0.008      -0.679      -0.100
# Book_Value_Unit_Curr           -0.1514      0.012    -12.174      0.000      -0.176      -0.127
# CEPS_annualised_Unit_Curr      -0.0972      0.013     -7.649      0.000      -0.122      -0.072
# Curr_Ratio_Latest              -0.4580      0.097     -4.733      0.000      -0.648      -0.268
# Interest_Cover_Ratio_Latest    -0.0024      0.001     -2.999      0.003      -0.004      -0.001
# ===============================================================================================
#
# Possibly complete quasi-separation: A fraction 0.42 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.

# %% [markdown]
# ### Training Set

# %%
y_prob_pred_train = best_model.predict(df_train)

# %%
fpr, tpr, thresholds = roc_curve(df_train['Default'], y_prob_pred_train)

# %%
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
optimal_threshold
# Out:
# 0.24132824091512983

# %%
y_class_pred=[]
for i in range(0,len(y_prob_pred_train)):
    if np.array(y_prob_pred_train)[i] > optimal_threshold:
        a=1
    else:
        a=0
    y_class_pred.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(df_train['Default'],y_class_pred)),annot=True,fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %%
print(metrics.classification_report(df_train['Default'], y_class_pred, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.988     0.963     0.975      2140
#            1      0.747     0.900     0.816       259
#
#     accuracy                          0.956      2399
#    macro avg      0.867     0.931     0.896      2399
# weighted avg      0.962     0.956     0.958      2399

# %%
auc = roc_auc_score(df_train['Default'], y_prob_pred_train)
print('AUC: %.3f' % auc)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
plt.title('Test Data - ROC Curve')
# Out:
# AUC: 0.975
# Text(0.5, 1.0, 'Test Data - ROC Curve')

# %% [markdown]
# ### Testing Set

# %%
y_prob_pred_test = best_model.predict(df_test)

# %%
fpr, tpr, thresholds = roc_curve(df_test['Default'], y_prob_pred_test)

# %%
y_class_pred=[]
for i in range(0,len(y_prob_pred_test)):
    if np.array(y_prob_pred_test)[i] > optimal_threshold:
        a=1
    else:
        a=0
    y_class_pred.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(df_test['Default'], y_class_pred)), annot = True,fmt = '.5g', cmap = 'Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals', rotation=0);

# %%
print(metrics.classification_report(df_test['Default'], y_class_pred, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.987     0.959     0.973      1055
#            1      0.726     0.898     0.803       127
#
#     accuracy                          0.953      1182
#    macro avg      0.857     0.928     0.888      1182
# weighted avg      0.959     0.953     0.955      1182

# %%
auc = roc_auc_score(df_test['Default'], y_prob_pred_test)
print('AUC: %.3f' % auc)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
plt.title('Test Data - ROC Curve')
# Out:
# AUC: 0.956
# Text(0.5, 1.0, 'Test Data - ROC Curve')

# %% [markdown]
# ## Final Metrics - Logit using SM without SMOTE

# %%
final_logit_sm_metrics=pd.concat([df_metrics_train_logit.sort_values(by='Accuracy',ascending=False)[['Accuracy','Precision','Recall',
                                                                              'F1 Score','AUC']
                                                                            ].head(1),
           df_metrics_test_logit.sort_values(by='Accuracy',ascending=False)[['Accuracy','Precision','Recall',
                                                                             'F1 Score','AUC']
                                                                           ].head(1)])
final_logit_sm_metrics.index=['Logit_SM_Train','Logit_SM_Test']

# %%
final_logit_sm_metrics
# Out:
#                 Accuracy  Precision    Recall  F1 Score       AUC
# Logit_SM_Train  0.958316   0.760656  0.895753  0.822695  0.975275
# Logit_SM_Test   0.952623   0.726115  0.897638  0.802817  0.956256

# %% [markdown]
# ## Evaluating for SMOTE data

# %%
model_list_smote,df_metrics_train_smote_logit,df_metrics_test_smote_logit=logit_model_eval(df_train_smote,
                                                                                     df_test_smote,
                                                                         num_of_models=200)

# %%
df_metrics_train_smote_logit.sort_values(by='Accuracy',ascending=False)
# Out:
#    ModelType Model_Name  Accuracy  F1 Score    Recall  Precision  \
# 17     Logit   Model_18  0.950245  0.948712  0.920131   0.979125
# 0      Logit    Model_1  0.948844  0.947520  0.923400   0.972933
# 1      Logit    Model_2  0.948844  0.947444  0.921999   0.974334
# 5      Logit    Model_6  0.948610  0.947267  0.922933   0.972920
# 6      Logit    Model_7  0.948610  0.947242  0.922466   0.973386
# 18     Logit   Model_19  0.948610  0.947115  0.920131   0.975731
# 4      Logit    Model_5  0.948610  0.947192  0.921532   0.974321
# 3      Logit    Model_4  0.948610  0.947192  0.921532   0.974321
# 7      Logit    Model_8  0.947909  0.946510  0.921532   0.972880
# 8      Logit    Model_9  0.947676  0.946283  0.921532   0.972400
# 10     Logit   Model_11  0.947442  0.945848  0.917795   0.975670
# 11     Logit   Model_12  0.947442  0.946645  0.932275   0.961464
# 13     Logit   Model_14  0.947442  0.946108  0.922466   0.970993
# 15     Logit   Model_16  0.947442  0.946695  0.933209   0.960577
# 9      Logit   Model_10  0.947442  0.945874  0.918262   0.975198
# 16     Logit   Model_17  0.946741  0.945972  0.932275   0.960077
# 12     Logit   Model_13  0.945807  0.944365  0.919664   0.970429
# 14     Logit   Model_15  0.945573  0.944642  0.928538   0.961315
# 2      Logit    Model_3  0.879000  0.876667  0.859879   0.894123
#
#     Optimal_Thresh       AUC                     Dropped_Column  \
# 17        0.692248  0.981177                 Creditors_Vel_Days
# 0         0.685303  0.982360                 PBIDTM_perc_Latest
# 1         0.687381  0.982361                     Equity_Paid_Up
# 5         0.683443  0.982355                        Curr_Assets
# 6         0.684417  0.982338              ROG_Cost_of_Prod_perc
# 18        0.689968  0.980369                       Selling_Cost
# 4         0.688237  0.982355               ROG_Gross_Block_perc
# 3         0.687949  0.982362                   Rev_exp_in_forex
# 7         0.684858  0.982310     ROG_Market_Capitalisation_perc
# 8         0.683350  0.982322          ROG_Rev_exp_in_forex_perc
# 10        0.691919  0.982262               Capital_exp_in_forex
# 11        0.644946  0.982248          ROG_Capital_Employed_perc
# 13        0.683587  0.981004                 Inventory_Vel_Days
# 15        0.654711  0.980926  Total_Asset_Turnover_Ratio_Latest
# 9         0.690908  0.982300                Net_Working_Capital
# 16        0.651390  0.980997    Value_of_Output_to_Total_Assets
# 12        0.684699  0.980989                   Debtors_Vel_Days
# 14        0.662035  0.980887               Debtors_Ratio_Latest
# 2         0.570510  0.941221           Book_Value_Adj_Unit_Curr
#
#     Dropped_col_pvalue
# 17            0.055022
# 0             0.859589
# 1             0.841399
# 5             0.704788
# 6             0.486819
# 18            0.020782
# 4             0.733460
# 3             0.773915
# 7             0.469363
# 8             0.418350
# 10            0.160489
# 11            0.118446
# 13            0.075108
# 15            0.075280
# 9             0.246522
# 16            0.065417
# 12            0.078762
# 14            0.069276
# 2             0.995610

# %%
df_metrics_test_smote_logit.sort_values(by='Accuracy',ascending=False)
# Out:
#    ModelType Model_Name  Accuracy  F1 Score    Recall  Precision       AUC  \
# 17     Logit   Model_18  0.945472  0.944418  0.926945   0.962562  0.974799
# 18     Logit   Model_19  0.944049  0.942829  0.923150   0.963366  0.974473
# 13     Logit   Model_14  0.943575  0.942595  0.926945   0.958783  0.974694
# 1      Logit    Model_2  0.942627  0.941404  0.922201   0.961424  0.975607
# 3      Logit    Model_4  0.942153  0.940949  0.922201   0.960474  0.975415
# 12     Logit   Model_13  0.942153  0.941063  0.924099   0.958661  0.975445
# 4      Logit    Model_5  0.941679  0.940436  0.921252   0.960435  0.975299
# 6      Logit    Model_7  0.941679  0.940493  0.922201   0.959526  0.975382
# 14     Logit   Model_15  0.941204  0.940499  0.929791   0.951456  0.974629
# 0      Logit    Model_1  0.941204  0.940039  0.922201   0.958580  0.975621
# 5      Logit    Model_6  0.941204  0.940039  0.922201   0.958580  0.975310
# 15     Logit   Model_16  0.940730  0.940277  0.933586   0.947064  0.974595
# 16     Logit   Model_17  0.940730  0.940334  0.934535   0.946206  0.974593
# 10     Logit   Model_11  0.940256  0.938894  0.918406   0.960317  0.974954
# 8      Logit    Model_9  0.939782  0.938677  0.922201   0.955752  0.975283
# 7      Logit    Model_8  0.939782  0.938618  0.921252   0.956650  0.975266
# 9      Logit   Model_10  0.939782  0.938439  0.918406   0.959366  0.975259
# 11     Logit   Model_12  0.937885  0.937530  0.932638   0.942474  0.975042
# 2      Logit    Model_3  0.864865  0.860772  0.835863   0.887210  0.933526
#
#     Optimal_Thresh                     Dropped_Column  Dropped_col_pvalue
# 17        0.692248                 Creditors_Vel_Days            0.055022
# 18        0.689968                       Selling_Cost            0.020782
# 13        0.683587                 Inventory_Vel_Days            0.075108
# 1         0.687381                     Equity_Paid_Up            0.841399
# 3         0.687949                   Rev_exp_in_forex            0.773915
# 12        0.684699                   Debtors_Vel_Days            0.078762
# 4         0.688237               ROG_Gross_Block_perc            0.733460
# 6         0.684417              ROG_Cost_of_Prod_perc            0.486819
# 14        0.662035               Debtors_Ratio_Latest            0.069276
# 0         0.685303                 PBIDTM_perc_Latest            0.859589
# 5         0.683443                        Curr_Assets            0.704788
# 15        0.654711  Total_Asset_Turnover_Ratio_Latest            0.075280
# 16        0.651390    Value_of_Output_to_Total_Assets            0.065417
# 10        0.691919               Capital_exp_in_forex            0.160489
# 8         0.683350          ROG_Rev_exp_in_forex_perc            0.418350
# 7         0.684858     ROG_Market_Capitalisation_perc            0.469363
# 9         0.690908                Net_Working_Capital            0.246522
# 11        0.644946          ROG_Capital_Employed_perc            0.118446
# 2         0.570510           Book_Value_Adj_Unit_Curr            0.995610

# %%
best_model_smote=model_list[df_metrics_test_smote_logit.sort_values(by='Accuracy',ascending=False).index[0]]
best_model_smote

# %%
print(best_model_smote.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Default   No. Observations:                 2399
# Model:                          Logit   Df Residuals:                     2381
# Method:                           MLE   Df Model:                           17
# Date:                Wed, 24 Feb 2021   Pseudo R-squ.:                  0.6508
# Time:                        20:24:56   Log-Likelihood:                -286.68
# converged:                       True   LL-Null:                       -821.02
# Covariance Type:            nonrobust   LLR p-value:                1.821e-216
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -0.2385      0.162     -1.469      0.142      -0.557       0.080
# Net_Working_Capital                 0.0003      0.000      1.581      0.114   -8.13e-05       0.001
# Curr_Assets                      7.663e-05    5.4e-05      1.419      0.156   -2.92e-05       0.000
# Other_Income                       -0.0072      0.006     -1.215      0.224      -0.019       0.004
# Rev_earn_in_forex                   0.0020      0.001      2.139      0.032       0.000       0.004
# Book_Value_Unit_Curr               -0.1549      0.013    -11.672      0.000      -0.181      -0.129
# Market_Capitalisation              -0.0007      0.001     -1.171      0.242      -0.002       0.000
# CEPS_annualised_Unit_Curr          -0.0944      0.014     -6.642      0.000      -0.122      -0.067
# Cash_Flow_From_Opr                  0.0013      0.001      1.019      0.308      -0.001       0.004
# ROG_Gross_Block_perc               -0.0048      0.004     -1.277      0.202      -0.012       0.003
# ROG_PAT_perc                     6.173e-05   4.36e-05      1.415      0.157   -2.38e-05       0.000
# ROG_Rev_earn_in_forex_perc         -0.0035      0.004     -1.010      0.313      -0.010       0.003
# Curr_Ratio_Latest                  -0.4605      0.097     -4.769      0.000      -0.650      -0.271
# Inventory_Ratio_Latest             -0.0026      0.002     -1.646      0.100      -0.006       0.000
# Interest_Cover_Ratio_Latest        -0.0023      0.001     -2.764      0.006      -0.004      -0.001
# CPM_perc_Latest                    -0.0001   9.86e-05     -1.029      0.303      -0.000    9.17e-05
# Creditors_Vel_Days               7.117e-06   7.24e-06      0.983      0.325   -7.07e-06    2.13e-05
# Value_of_Output_to_Total_Assets    -0.0823      0.096     -0.859      0.390      -0.270       0.105
# ===================================================================================================
#
# Possibly complete quasi-separation: A fraction 0.44 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.

# %%
y_prob_pred_train_smote = best_model_smote.predict(df_train_smote)

# %%
fpr_smote, tpr_smote, thresholds_smote = roc_curve(df_train_smote['Default'], y_prob_pred_train_smote)

# %%
optimal_idx_smote = np.argmax(tpr_smote - fpr_smote)
optimal_threshold_smote = thresholds_smote[optimal_idx_smote]
optimal_threshold_smote
# Out:
# 0.21506360902228425

# %%
y_class_pred_smote=[]
for i in range(0,len(y_prob_pred_train_smote)):
    if np.array(y_prob_pred_train_smote)[i] > optimal_threshold_smote:
        a=1
    else:
        a=0
    y_class_pred_smote.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(df_train_smote['Default'],y_class_pred_smote)),annot=True,
            fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %%
print(metrics.classification_report(df_train_smote['Default'], y_class_pred_smote, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.934     0.953     0.944      2140
#            1      0.952     0.933     0.942      2141
#
#     accuracy                          0.943      4281
#    macro avg      0.943     0.943     0.943      4281
# weighted avg      0.943     0.943     0.943      4281

# %%
auc = roc_auc_score(df_train_smote['Default'], y_prob_pred_train_smote)
print('AUC: %.3f' % auc)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
plt.title('Test Data - ROC Curve')
# Out:
# AUC: 0.975
# Text(0.5, 1.0, 'Test Data - ROC Curve')

# %%
y_prob_pred_test_smote = best_model_smote.predict(df_test_smote)

# %%
y_class_pred_smote=[]
for i in range(0,len(y_prob_pred_test_smote)):
    if np.array(y_prob_pred_test_smote)[i] > optimal_threshold_smote:
        a=1
    else:
        a=0
    y_class_pred_smote.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(df_test_smote['Default'], y_class_pred_smote)), annot = True,
            fmt = '.5g', cmap = 'Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals', rotation=0);

# %%
print(metrics.classification_report(df_test_smote['Default'], y_class_pred_smote, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.940     0.942     0.941      1055
#            1      0.942     0.940     0.941      1054
#
#     accuracy                          0.941      2109
#    macro avg      0.941     0.941     0.941      2109
# weighted avg      0.941     0.941     0.941      2109

# %%
auc = roc_auc_score(df_test_smote['Default'], y_prob_pred_test_smote)
print('AUC: %.3f' % auc)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
plt.title('Test Data - ROC Curve')
# Out:
# AUC: 0.970
# Text(0.5, 1.0, 'Test Data - ROC Curve')

# %% [markdown]
# ## Final Metrics - Logit using SM with SMOTE

# %%
final_logit_sm_smote_metrics=pd.concat([df_metrics_train_smote_logit.sort_values(by='Accuracy',ascending=False)[['Accuracy','Precision','Recall',
                                                                              'F1 Score','AUC']
                                                                            ].head(1),
           df_metrics_test_smote_logit.sort_values(by='Accuracy',ascending=False)[['Accuracy','Precision','Recall',
                                                                             'F1 Score','AUC']
                                                                           ].head(1)])
final_logit_sm_smote_metrics.index=['Logit_SM_Train_SMOTE','Logit_SM_Test_SMOTE']

# %%
final_logit_sm_smote_metrics
# Out:
#                       Accuracy  Precision    Recall  F1 Score       AUC
# Logit_SM_Train_SMOTE  0.950245   0.979125  0.920131  0.948712  0.981177
# Logit_SM_Test_SMOTE   0.945472   0.962562  0.926945  0.944418  0.974799

# %% [markdown]
# ## Generic Function for other models

# %%
def apply_evl(name,model,param_grid,X_train,X_test,y_train,y_test):
    test_metrics_dict={}
    train_metrics_dict={}
    from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,f1_score,precision_score,recall_score,roc_auc_score
    from sklearn.model_selection import GridSearchCV
    print(name)
    if param_grid!=None:    
        grid_search = GridSearchCV(estimator = model, param_grid = param_grid, cv = 3,n_jobs=4)
        gs=grid_search.fit(X_train,y_train)
        print("--------------------Best Parameters--------------------")
        print(gs.best_params_)
        best_model=gs.best_estimator_
        print()
        print()
        print("--------------------Best Model Params--------------------")
        print(best_model)
        print()
        print()
        ytrain_predict = best_model.predict(X_train)
        ytest_predict = best_model.predict(X_test)
    elif param_grid == None:
        best_model=model
        best_model.fit(X_train,y_train)
        ytrain_predict = best_model.predict(X_train)
        ytest_predict = best_model.predict(X_test)
    
    print("Train Accuracy Score for model {} is {}".format(model,accuracy_score(y_train,ytrain_predict)))
    print()
    print()
    print("--------------------Classification Report - Train Data--------------------")
    print(classification_report(y_train,ytrain_predict))
    print("------------------------------------------------------------")
    print()
    print()
    sns.heatmap(confusion_matrix(y_train,ytrain_predict),annot=True, fmt='d',
            cbar=False,cmap='YlGnBu')
    plt.xlabel('Predicted Label')
    plt.ylabel('Actual Label')
    plt.title('Confusion Matrix - Train Data')
    plt.show()
    print()
    print()
    print("------------------------------------------------------------")
    
        # AUC and ROC for the training data

    # predict probabilities
    probs = best_model.predict_proba(X_train)
    # keep probabilities for the positive outcome only
    probs = probs[:, 1]
    # calculate AUC
    from sklearn.metrics import roc_auc_score
    auc = roc_auc_score(y_train, probs)
    print('AUC: %.3f' % auc)
    # calculate roc curve
    from sklearn.metrics import roc_curve
    fpr_train, tpr_train, thresholds = roc_curve(y_train, probs)
    plt.plot([0, 1], [0, 1], linestyle='--')
    # plot the roc curve for the model
    plt.plot(fpr_train, tpr_train, marker='.')
    plt.title('Train Data - ROC Curve')
    # show the plot
    plt.show()
    print()
    print()
    print("------------------------------------------------------------")
    
        
#     train_metrics_dict.update({"Accuracy":accuracy_score(y_train,ytrain_predict)})
#     train_metrics_dict.update({"Precision":precision_score(y_train,ytrain_predict)})
#     train_metrics_dict.update({"Recall":recall_score(y_train,ytrain_predict)})
#     train_metrics_dict.update({"F1":f1_score(y_train,ytrain_predict)})
#     train_metrics_dict.update({"AUC":roc_auc_score(y_train,probs)})
#     train_metrics_df=pd.DataFrame(train_metrics_dict,index=[name+"_Train"]).T

    train_metrics_dict.update({name+"_Train":[accuracy_score(y_train,ytrain_predict),precision_score(y_train,ytrain_predict),
                                                recall_score(y_train,ytrain_predict),f1_score(y_train,ytrain_predict),
                                                roc_auc_score(y_train,probs),fpr_train,tpr_train]})
    train_metrics_df=pd.DataFrame(train_metrics_dict,index=['Accuracy','Precision','Recall','F1','AUC','FPR',
                                                            'TPR'])
    
    
    print()
    print()
    
    print("Test Accuracy Score for model {} is {}".format(model,accuracy_score(y_test,ytest_predict)))
    print()
    print()
    print("--------------------Classification Report - Test Data--------------------")
    print(classification_report(y_test,ytest_predict))
    print("------------------------------------------------------------")
    print()
    print()
    sns.heatmap(confusion_matrix(y_test,ytest_predict),annot=True, fmt='d',
            cbar=False,cmap='YlGnBu')
    plt.xlabel('Predicted Label')
    plt.ylabel('Actual Label')
    plt.title('Confusion Matrix - Test Data')
    plt.show()
    print()
    print()
    print("------------------------------------------------------------")
    
        # AUC and ROC for the training data

    # predict probabilities
    probs = best_model.predict_proba(X_test)
    # keep probabilities for the positive outcome only
    probs = probs[:, 1]
    # calculate AUC
    from sklearn.metrics import roc_auc_score
    auc = roc_auc_score(y_test, probs)
    print('AUC: %.3f' % auc)
    # calculate roc curve
    from sklearn.metrics import roc_curve
    fpr_test, tpr_test, thresholds = roc_curve(y_test, probs)
    plt.plot([0, 1], [0, 1], linestyle='--')
    # plot the roc curve for the model
    plt.plot(fpr_test, tpr_test, marker='.')
    plt.title('Test Data - ROC Curve')
    # show the plot
    plt.show()
    print()
    print()
    print("------------------------------------------------------------")
       
    
    test_metrics_dict.update({name+"_Test":[accuracy_score(y_test,ytest_predict),precision_score(y_test,ytest_predict),
                                            recall_score(y_test,ytest_predict),f1_score(y_test,ytest_predict),
                                            roc_auc_score(y_test,probs),fpr_test,tpr_test]})
    test_metrics_df=pd.DataFrame(test_metrics_dict,index=['Accuracy','Precision','Recall','F1','AUC','FPR'])
    return pd.concat([train_metrics_df,test_metrics_df],axis=1),best_model

# %% [markdown]
# ## Logit Using Sklearn - All Unscaled Without SMOTE

# %%
param_grid_lr_unscaled={'penalty':['l1','l2', 'elasticnet', 'none'],
      'solver':['sag','lbfgs','liblinear','newton-cg','saga'],
      'tol':[0.0001,0.00001,0.000001,0.0000001,0.00000001],
      'max_iter':[100,200,300],
               'random_state':[0,1,21,23]}

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
final_logit_sklearn_unscaled_metrics,best_model_lr=apply_evl("LogisticRegression_Unscaled",lr,
                                                              param_grid_lr_unscaled,
                                     X_train,X_test,y_train,y_test)
# Out:
# LogisticRegression_Unscaled
# --------------------Best Parameters--------------------
# {'max_iter': 300, 'penalty': 'l2', 'random_state': 0, 'solver': 'lbfgs', 'tol': 0.0001}
#
#
# --------------------Best Model Params--------------------
# LogisticRegression(max_iter=300, random_state=0)
#
#
# Train Accuracy Score for model LogisticRegression() is 0.972488536890371
#
#
# --------------------Classification Report - Train Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      2140
#            1       0.93      0.80      0.86       259
#
#     accuracy                           0.97      2399
#    macro avg       0.95      0.90      0.92      2399
# weighted avg       0.97      0.97      0.97      2399
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.966
# ------------------------------------------------------------
#
#
# Test Accuracy Score for model LogisticRegression() is 0.9593908629441624
#
#
# --------------------Classification Report - Test Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1055
#            1       0.87      0.73      0.79       127
#
#     accuracy                           0.96      1182
#    macro avg       0.92      0.86      0.89      1182
# weighted avg       0.96      0.96      0.96      1182
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.946
# ------------------------------------------------------------

# %%
final_logit_sklearn_unscaled_metrics.T[['Accuracy','Precision','Recall','F1','AUC']]
# Out:
#                                    Accuracy Precision    Recall        F1  \
# LogisticRegression_Unscaled_Train  0.972489  0.932735  0.803089  0.863071
# LogisticRegression_Unscaled_Test   0.959391  0.869159  0.732283  0.794872
#
#                                         AUC
# LogisticRegression_Unscaled_Train  0.966442
# LogisticRegression_Unscaled_Test   0.945725

# %% [markdown]
# ## Logit Using Sklearn - Scaled Without SMOTE

# %%
param_grid_lr_scaled={'penalty':['l1','l2', 'elasticnet', 'none'],
      'solver':['sag','lbfgs','liblinear','newton-cg','saga'],
      'tol':[0.0001,0.00001,0.000001,0.0000001,0.00000001],
      'max_iter':[100,200,300],
               'random_state':[0,1,21,23]}

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
final_logit_sklearn_scaled_metrics,best_model_lr=apply_evl("LogisticRegression_Scaled",lr,param_grid_lr_scaled,
                                     X_train_all_scaled,X_test_all_scaled,y_train_all_scaled,y_test_all_scaled)
# Out:
# LogisticRegression_Scaled
# --------------------Best Parameters--------------------
# {'max_iter': 100, 'penalty': 'none', 'random_state': 0, 'solver': 'newton-cg', 'tol': 0.0001}
#
#
# --------------------Best Model Params--------------------
# LogisticRegression(penalty='none', random_state=0, solver='newton-cg')
#
#
# Train Accuracy Score for model LogisticRegression() is 0.964568570237599
#
#
# --------------------Classification Report - Train Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      2140
#            1       0.94      0.71      0.81       259
#
#     accuracy                           0.96      2399
#    macro avg       0.96      0.85      0.90      2399
# weighted avg       0.96      0.96      0.96      2399
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.977
# ------------------------------------------------------------
#
#
# Test Accuracy Score for model LogisticRegression() is 0.9517766497461929
#
#
# --------------------Classification Report - Test Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      1055
#            1       0.83      0.69      0.76       127
#
#     accuracy                           0.95      1182
#    macro avg       0.90      0.84      0.86      1182
# weighted avg       0.95      0.95      0.95      1182
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.945
# ------------------------------------------------------------

# %%
final_logit_sklearn_scaled_metrics.T[['Accuracy','Precision','Recall','F1','AUC']]
# Out:
#                                  Accuracy Precision    Recall        F1  \
# LogisticRegression_Scaled_Train  0.964569  0.943878  0.714286  0.813187
# LogisticRegression_Scaled_Test   0.951777  0.830189  0.692913  0.755365
#
#                                       AUC
# LogisticRegression_Scaled_Train   0.97694
# LogisticRegression_Scaled_Test   0.945098

# %% [markdown]
# ## Logit Using Sklearn - Unscaled With Smote

# %%
param_grid_lr_unscaled_smote={'penalty':['l1','l2', 'elasticnet', 'none'],
      'solver':['sag','lbfgs','liblinear','newton-cg','saga'],
      'tol':[0.0001,0.00001,0.000001,0.0000001,0.00000001],
      'max_iter':[100,200,300],
               'random_state':[0,1,21,23]}

# %%
from sklearn.linear_model import LogisticRegression
lr_smote = LogisticRegression()
final_logit_sklearn_unscalled_smote_metrics,best_model_lr_smote=apply_evl("LogisticRegression_With_Smote",lr_smote,
                                                                    param_grid_lr_unscaled_smote,
                                     X_train_smote,X_test_smote,y_train_smote,y_test_smote)
# Out:
# LogisticRegression_With_Smote
# --------------------Best Parameters--------------------
# {'max_iter': 300, 'penalty': 'l2', 'random_state': 0, 'solver': 'lbfgs', 'tol': 0.0001}
#
#
# --------------------Best Model Params--------------------
# LogisticRegression(max_iter=300, random_state=0)
#
#
# Train Accuracy Score for model LogisticRegression() is 0.9397337070777856
#
#
# --------------------Classification Report - Train Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      2140
#            1       0.96      0.91      0.94      2141
#
#     accuracy                           0.94      4281
#    macro avg       0.94      0.94      0.94      4281
# weighted avg       0.94      0.94      0.94      4281
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.973
# ------------------------------------------------------------
#
#
# Test Accuracy Score for model LogisticRegression() is 0.9355144618302513
#
#
# --------------------Classification Report - Test Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94      1055
#            1       0.94      0.93      0.93      1054
#
#     accuracy                           0.94      2109
#    macro avg       0.94      0.94      0.94      2109
# weighted avg       0.94      0.94      0.94      2109
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.969
# ------------------------------------------------------------

# %%
final_logit_sklearn_unscalled_smote_metrics.T[['Accuracy','Precision','Recall','F1','AUC']]
# Out:
#                                      Accuracy Precision    Recall        F1  \
# LogisticRegression_With_Smote_Train  0.939734  0.963109  0.914526  0.938189
# LogisticRegression_With_Smote_Test   0.935514   0.94305  0.926945  0.934928
#
#                                           AUC
# LogisticRegression_With_Smote_Train  0.972807
# LogisticRegression_With_Smote_Test   0.968668

# %% [markdown]
# ## Logit Using Sklearn - Scaled With Smote

# %%
param_grid_lr_scaled_smote={'penalty':['l1','l2', 'elasticnet', 'none'],
      'solver':['sag','lbfgs','liblinear','newton-cg','saga'],
      'tol':[0.0001,0.00001,0.000001,0.0000001,0.00000001],
      'max_iter':[100,200,300],
               'random_state':[0,1,21,23]}

# %%
from sklearn.linear_model import LogisticRegression
lr_smote = LogisticRegression()
final_logit_sklearn_scalled_smote_metrics,best_model_lr_smote=apply_evl("LogisticRegression_Scaled_With_Smote",
                                                                        lr_smote,
                                                                    param_grid_lr_scaled_smote,
                                     X_train_smote_all_scaled,X_test_smote_all_scaled,
                                                                        y_train_smote_all_scaled,
                                                                        y_test_smote_all_scaled)
# Out:
# LogisticRegression_Scaled_With_Smote
# --------------------Best Parameters--------------------
# {'max_iter': 300, 'penalty': 'none', 'random_state': 0, 'solver': 'lbfgs', 'tol': 0.0001}
#
#
# --------------------Best Model Params--------------------
# LogisticRegression(max_iter=300, penalty='none', random_state=0)
#
#
# Train Accuracy Score for model LogisticRegression() is 0.9366970334034104
#
#
# --------------------Classification Report - Train Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.94      2140
#            1       0.92      0.96      0.94      2141
#
#     accuracy                           0.94      4281
#    macro avg       0.94      0.94      0.94      4281
# weighted avg       0.94      0.94      0.94      4281
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.982
# ------------------------------------------------------------
#
#
# Test Accuracy Score for model LogisticRegression() is 0.9288762446657184
#
#
# --------------------Classification Report - Test Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93      1055
#            1       0.90      0.96      0.93      1054
#
#     accuracy                           0.93      2109
#    macro avg       0.93      0.93      0.93      2109
# weighted avg       0.93      0.93      0.93      2109
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.975
# ------------------------------------------------------------

# %%
final_logit_sklearn_scalled_smote_metrics.T[['Accuracy','Precision','Recall','F1','AUC']]
# Out:
#                                             Accuracy Precision    Recall  \
# LogisticRegression_Scaled_With_Smote_Train  0.936697  0.917038  0.960299
# LogisticRegression_Scaled_With_Smote_Test   0.928876  0.902135  0.962049
#
#                                                   F1       AUC
# LogisticRegression_Scaled_With_Smote_Train   0.93817  0.982349
# LogisticRegression_Scaled_With_Smote_Test   0.931129   0.97516

# %% [markdown]
# ## Linear Discriminant Analysis using sklearn

# %% [markdown]
# Linear Discriminant Analysis (LDA) finds it's coefficients using the variation between the classes (check this), so the scaling doesn't matter.

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier

# %%
param_grid_lda = {'solver': ['svd', 'lsqr', 'eigen'],
              'shrinkage': ['auto', 'none', 'default'],
              'tol': [0.000001, 0.0000001, 0.000000001]}

# %%
lda = LinearDiscriminantAnalysis()
lda_metrics_df,best_model_lda=apply_evl("LDA",lda,param_grid_lda,X_train,X_test,
          y_train,y_test)
# Out:
# LDA
# --------------------Best Parameters--------------------
# {'shrinkage': 'auto', 'solver': 'lsqr', 'tol': 1e-06}
#
#
# --------------------Best Model Params--------------------
# LinearDiscriminantAnalysis(shrinkage='auto', solver='lsqr', tol=1e-06)
#
#
# Train Accuracy Score for model LinearDiscriminantAnalysis() is 0.8920383493122134
#
#
# --------------------Classification Report - Train Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      2140
#            1       0.50      0.01      0.02       259
#
#     accuracy                           0.89      2399
#    macro avg       0.70      0.51      0.48      2399
# weighted avg       0.85      0.89      0.84      2399
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.740
# ------------------------------------------------------------
#
#
# Test Accuracy Score for model LinearDiscriminantAnalysis() is 0.8900169204737732
#
#
# --------------------Classification Report - Test Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94      1055
#            1       0.33      0.02      0.04       127
#
#     accuracy                           0.89      1182
#    macro avg       0.61      0.51      0.49      1182
# weighted avg       0.83      0.89      0.85      1182
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.683
# ------------------------------------------------------------

# %%
lda_metrics_df.T[['Accuracy','Precision','Recall','F1','AUC']]
# Out:
#            Accuracy Precision    Recall         F1       AUC
# LDA_Train  0.892038       0.5  0.011583  0.0226415  0.740082
# LDA_Test   0.890017  0.333333  0.023622  0.0441176  0.683203

# %% [markdown]
# ## LDA with Smote using sklearn

# %%
param_grid_lda_smote = {'solver': ['svd', 'lsqr', 'eigen'],
              'shrinkage': ['auto', 'none', 'default'],
              'tol': [0.000001, 0.0000001, 0.000000001]}

# %%
lda_smote = LinearDiscriminantAnalysis()
lda_metrics_df_smote,best_model_lda_smote=apply_evl("LDA_With_Smote",lda_smote,param_grid_lda_smote,X_train_smote,
                                                    X_test_smote,y_train_smote,y_test_smote)
# Out:
# LDA_With_Smote
# --------------------Best Parameters--------------------
# {'shrinkage': 'auto', 'solver': 'lsqr', 'tol': 1e-06}
#
#
# --------------------Best Model Params--------------------
# LinearDiscriminantAnalysis(shrinkage='auto', solver='lsqr', tol=1e-06)
#
#
# Train Accuracy Score for model LinearDiscriminantAnalysis() is 0.6598925484699837
#
#
# --------------------Classification Report - Train Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.49      0.59      2140
#            1       0.62      0.83      0.71      2141
#
#     accuracy                           0.66      4281
#    macro avg       0.68      0.66      0.65      4281
# weighted avg       0.68      0.66      0.65      4281
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.725
# ------------------------------------------------------------
#
#
# Test Accuracy Score for model LinearDiscriminantAnalysis() is 0.6429587482219061
#
#
# --------------------Classification Report - Test Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.72      0.47      0.57      1055
#            1       0.61      0.81      0.70      1054
#
#     accuracy                           0.64      2109
#    macro avg       0.66      0.64      0.63      2109
# weighted avg       0.66      0.64      0.63      2109
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.703
# ------------------------------------------------------------

# %%
lda_metrics_df_smote.T[['Accuracy','Precision','Recall','F1','AUC']]
# Out:
#                       Accuracy Precision    Recall        F1       AUC
# LDA_With_Smote_Train  0.659893    0.6188  0.833255  0.710191  0.724862
# LDA_With_Smote_Test   0.642959   0.60621  0.814991  0.695265  0.702944

# %% [markdown]
# ## Random Forest using sklearn

# %% [markdown]
# Tree based models are not distance based models and can handle varying ranges of features. Hence, Scaling is not required while modelling trees.

# %%
param_grid_rf = {
    'max_depth': [10,20,30],
    'max_features': [2,3,4,5,6,7,8],
    'min_samples_leaf': [25,50,75,100],
    'min_samples_split': [25,50,75,100],
    'n_estimators': [50,100,150]
}

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_metrics_df,best_model_rf=apply_evl("RandomForest",rf_model,param_grid_rf,
                                             X_train,X_test,y_train,y_test)
# Out:
# RandomForest
# --------------------Best Parameters--------------------
# {'max_depth': 10, 'max_features': 6, 'min_samples_leaf': 50, 'min_samples_split': 50, 'n_estimators': 100}
#
#
# --------------------Best Model Params--------------------
# RandomForestClassifier(max_depth=10, max_features=6, min_samples_leaf=50,
#                        min_samples_split=50)
#
#
# Train Accuracy Score for model RandomForestClassifier() is 0.9812421842434348
#
#
# --------------------Classification Report - Train Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2140
#            1       0.92      0.90      0.91       259
#
#     accuracy                           0.98      2399
#    macro avg       0.96      0.95      0.95      2399
# weighted avg       0.98      0.98      0.98      2399
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.994
# ------------------------------------------------------------
#
#
# Test Accuracy Score for model RandomForestClassifier() is 0.9746192893401016
#
#
# --------------------Classification Report - Test Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1055
#            1       0.91      0.85      0.88       127
#
#     accuracy                           0.97      1182
#    macro avg       0.94      0.92      0.93      1182
# weighted avg       0.97      0.97      0.97      1182
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.986
# ------------------------------------------------------------

# %%
rf_metrics_df.T[['Accuracy','Precision','Recall','F1','AUC']]
# Out:
#                     Accuracy Precision    Recall        F1       AUC
# RandomForest_Train  0.981242  0.924603  0.899614  0.911937   0.99399
# RandomForest_Test   0.974619  0.907563  0.850394  0.878049  0.985857

# %% [markdown]
# ## RandomFirst with Smote using sklearn

# %%
param_grid_rf_smote = {
    'max_depth': [10,20,30],
    'max_features': [2,3,4,5,6,7,8],
    'min_samples_leaf': [25,50,75,100],
    'min_samples_split': [25,50,75,100],
    'n_estimators': [50,100,150]
}

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model_smote = RandomForestClassifier()
rf_metrics_df_smote,best_model_rf_smote=apply_evl("RF_With_Smote",rf_model_smote,param_grid_rf_smote,
                                             X_train_smote,X_test_smote,
          y_train_smote,y_test_smote)
# Out:
# RF_With_Smote
# --------------------Best Parameters--------------------
# {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 25, 'min_samples_split': 25, 'n_estimators': 150}
#
#
# --------------------Best Model Params--------------------
# RandomForestClassifier(max_depth=30, max_features=3, min_samples_leaf=25,
#                        min_samples_split=25, n_estimators=150)
#
#
# Train Accuracy Score for model RandomForestClassifier() is 0.979677645409951
#
#
# --------------------Classification Report - Train Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      2140
#            1       0.99      0.97      0.98      2141
#
#     accuracy                           0.98      4281
#    macro avg       0.98      0.98      0.98      4281
# weighted avg       0.98      0.98      0.98      4281
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.998
# ------------------------------------------------------------
#
#
# Test Accuracy Score for model RandomForestClassifier() is 0.9701280227596017
#
#
# --------------------Classification Report - Test Data--------------------
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1055
#            1       0.97      0.97      0.97      1054
#
#     accuracy                           0.97      2109
#    macro avg       0.97      0.97      0.97      2109
# weighted avg       0.97      0.97      0.97      2109
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# AUC: 0.996
# ------------------------------------------------------------

# %%
rf_metrics_df_smote.T[['Accuracy','Precision','Recall','F1','AUC']]
# Out:
#                      Accuracy Precision    Recall        F1       AUC
# RF_With_Smote_Train  0.979678   0.98535  0.973844  0.979563  0.998354
# RF_With_Smote_Test   0.970128   0.97056  0.969639    0.9701  0.996038

# %% [markdown]
# ### Few modifications in column names

# %%
final_logit_sm_metrics.columns=['Accuracy','Precision','Recall','F1','AUC']
final_logit_sm_metrics
# Out:
#                 Accuracy  Precision    Recall        F1       AUC
# Logit_SM_Train  0.958316   0.760656  0.895753  0.822695  0.975275
# Logit_SM_Test   0.952623   0.726115  0.897638  0.802817  0.956256

# %%
final_logit_sm_smote_metrics.columns=['Accuracy','Precision','Recall','F1','AUC']
final_logit_sm_smote_metrics
# Out:
#                       Accuracy  Precision    Recall        F1       AUC
# Logit_SM_Train_SMOTE  0.950245   0.979125  0.920131  0.948712  0.981177
# Logit_SM_Test_SMOTE   0.945472   0.962562  0.926945  0.944418  0.974799

# %% [markdown]
# ## Comparison

# %%
data_df=pd.concat([final_logit_sm_metrics,
                   final_logit_sm_smote_metrics, 
                   final_logit_sklearn_unscaled_metrics.T[['Accuracy','Precision','Recall','F1','AUC']], 
                   final_logit_sklearn_scaled_metrics.T[['Accuracy','Precision','Recall','F1','AUC']], 
                   final_logit_sklearn_unscalled_smote_metrics.T[['Accuracy','Precision','Recall','F1','AUC']], 
                   final_logit_sklearn_scalled_smote_metrics.T[['Accuracy','Precision','Recall','F1','AUC']], 
                   lda_metrics_df.T[['Accuracy','Precision','Recall','F1','AUC']], 
                   lda_metrics_df_smote.T[['Accuracy','Precision','Recall','F1','AUC']], 
                   rf_metrics_df.T[['Accuracy','Precision','Recall','F1','AUC']], 
                   rf_metrics_df_smote.T[['Accuracy','Precision','Recall','F1','AUC']]],axis=0)

# %%
data_df
# Out:
#                                             Accuracy Precision    Recall  \
# Logit_SM_Train                              0.958316  0.760656  0.895753
# Logit_SM_Test                               0.952623  0.726115  0.897638
# Logit_SM_Train_SMOTE                        0.950245  0.979125  0.920131
# Logit_SM_Test_SMOTE                         0.945472  0.962562  0.926945
# LogisticRegression_Unscaled_Train           0.972489  0.932735  0.803089
# LogisticRegression_Unscaled_Test            0.959391  0.869159  0.732283
# LogisticRegression_Scaled_Train             0.964569  0.943878  0.714286
# LogisticRegression_Scaled_Test              0.951777  0.830189  0.692913
# LogisticRegression_With_Smote_Train         0.939734  0.963109  0.914526
# LogisticRegression_With_Smote_Test          0.935514   0.94305  0.926945
# LogisticRegression_Scaled_With_Smote_Train  0.936697  0.917038  0.960299
# LogisticRegression_Scaled_With_Smote_Test   0.928876  0.902135  0.962049
# LDA_Train                                   0.892038       0.5  0.011583
# LDA_Test                                    0.890017  0.333333  0.023622
# LDA_With_Smote_Train                        0.659893    0.6188  0.833255
# LDA_With_Smote_Test                         0.642959   0.60621  0.814991
# RandomForest_Train                          0.981242  0.924603  0.899614
# RandomForest_Test                           0.974619  0.907563  0.850394
# RF_With_Smote_Train                         0.979678   0.98535  0.973844
# RF_With_Smote_Test                          0.970128   0.97056  0.969639
#
#                                                    F1       AUC
# Logit_SM_Train                               0.822695  0.975275
# Logit_SM_Test                                0.802817  0.956256
# Logit_SM_Train_SMOTE                         0.948712  0.981177
# Logit_SM_Test_SMOTE                          0.944418  0.974799
# LogisticRegression_Unscaled_Train            0.863071  0.966442
# LogisticRegression_Unscaled_Test             0.794872  0.945725
# LogisticRegression_Scaled_Train              0.813187   0.97694
# LogisticRegression_Scaled_Test               0.755365  0.945098
# LogisticRegression_With_Smote_Train          0.938189  0.972807
# LogisticRegression_With_Smote_Test           0.934928  0.968668
# LogisticRegression_Scaled_With_Smote_Train    0.93817  0.982349
# LogisticRegression_Scaled_With_Smote_Test    0.931129   0.97516
# LDA_Train                                   0.0226415  0.740082
# LDA_Test                                    0.0441176  0.683203
# LDA_With_Smote_Train                         0.710191  0.724862
# LDA_With_Smote_Test                          0.695265  0.702944
# RandomForest_Train                           0.911937   0.99399
# RandomForest_Test                            0.878049  0.985857
# RF_With_Smote_Train                          0.979563  0.998354
# RF_With_Smote_Test                             0.9701  0.996038

# %% [markdown]
# ## Best Models

# %%
data_df.sort_values(by='Accuracy',ascending=False)
# Out:
#                                             Accuracy Precision    Recall  \
# RandomForest_Train                          0.981242  0.924603  0.899614
# RF_With_Smote_Train                         0.979678   0.98535  0.973844
# RandomForest_Test                           0.974619  0.907563  0.850394
# LogisticRegression_Unscaled_Train           0.972489  0.932735  0.803089
# RF_With_Smote_Test                          0.970128   0.97056  0.969639
# LogisticRegression_Scaled_Train             0.964569  0.943878  0.714286
# LogisticRegression_Unscaled_Test            0.959391  0.869159  0.732283
# Logit_SM_Train                              0.958316  0.760656  0.895753
# Logit_SM_Test                               0.952623  0.726115  0.897638
# LogisticRegression_Scaled_Test              0.951777  0.830189  0.692913
# Logit_SM_Train_SMOTE                        0.950245  0.979125  0.920131
# Logit_SM_Test_SMOTE                         0.945472  0.962562  0.926945
# LogisticRegression_With_Smote_Train         0.939734  0.963109  0.914526
# LogisticRegression_Scaled_With_Smote_Train  0.936697  0.917038  0.960299
# LogisticRegression_With_Smote_Test          0.935514   0.94305  0.926945
# LogisticRegression_Scaled_With_Smote_Test   0.928876  0.902135  0.962049
# LDA_Train                                   0.892038       0.5  0.011583
# LDA_Test                                    0.890017  0.333333  0.023622
# LDA_With_Smote_Train                        0.659893    0.6188  0.833255
# LDA_With_Smote_Test                         0.642959   0.60621  0.814991
#
#                                                    F1       AUC
# RandomForest_Train                           0.911937   0.99399
# RF_With_Smote_Train                          0.979563  0.998354
# RandomForest_Test                            0.878049  0.985857
# LogisticRegression_Unscaled_Train            0.863071  0.966442
# RF_With_Smote_Test                             0.9701  0.996038
# LogisticRegression_Scaled_Train              0.813187   0.97694
# LogisticRegression_Unscaled_Test             0.794872  0.945725
# Logit_SM_Train                               0.822695  0.975275
# Logit_SM_Test                                0.802817  0.956256
# LogisticRegression_Scaled_Test               0.755365  0.945098
# Logit_SM_Train_SMOTE                         0.948712  0.981177
# Logit_SM_Test_SMOTE                          0.944418  0.974799
# LogisticRegression_With_Smote_Train          0.938189  0.972807
# LogisticRegression_Scaled_With_Smote_Train    0.93817  0.982349
# LogisticRegression_With_Smote_Test           0.934928  0.968668
# LogisticRegression_Scaled_With_Smote_Test    0.931129   0.97516
# LDA_Train                                   0.0226415  0.740082
# LDA_Test                                    0.0441176  0.683203
# LDA_With_Smote_Train                         0.710191  0.724862
# LDA_With_Smote_Test                          0.695265  0.702944

# %%
data_df.sort_values(by='AUC',ascending=False)
# Out:
#                                             Accuracy  Precision    Recall  \
# RF_With_Smote_Train                         0.979678   0.985350  0.973844
# RF_With_Smote_Test                          0.970128   0.970560  0.969639
# RandomForest_Train                          0.981242   0.924603  0.899614
# RandomForest_Test                           0.974619   0.907563  0.850394
# LogisticRegression_Scaled_With_Smote_Train  0.936697   0.917038  0.960299
# Logit_SM_Train_SMOTE                        0.950245   0.979125  0.920131
# LogisticRegression_Scaled_Train             0.964569   0.943878  0.714286
# Logit_SM_Train                              0.958316   0.760656  0.895753
# LogisticRegression_Scaled_With_Smote_Test   0.928876   0.902135  0.962049
# Logit_SM_Test_SMOTE                         0.945472   0.962562  0.926945
# LogisticRegression_With_Smote_Train         0.939734   0.963109  0.914526
# LogisticRegression_With_Smote_Test          0.935514   0.943050  0.926945
# LogisticRegression_Unscaled_Train           0.972489   0.932735  0.803089
# Logit_SM_Test                               0.952623   0.726115  0.897638
# LogisticRegression_Unscaled_Test            0.959391   0.869159  0.732283
# LogisticRegression_Scaled_Test              0.951777   0.830189  0.692913
# LDA_Train                                   0.892038   0.500000  0.011583
# LDA_With_Smote_Train                        0.659893   0.618800  0.833255
# LDA_With_Smote_Test                         0.642959   0.606210  0.814991
# LDA_Test                                    0.890017   0.333333  0.023622
#
#                                                   F1       AUC
# RF_With_Smote_Train                         0.979563  0.998354
# RF_With_Smote_Test                          0.970100  0.996038
# RandomForest_Train                          0.911937  0.993990
# RandomForest_Test                           0.878049  0.985857
# LogisticRegression_Scaled_With_Smote_Train  0.938170  0.982349
# Logit_SM_Train_SMOTE                        0.948712  0.981177
# LogisticRegression_Scaled_Train             0.813187  0.976940
# Logit_SM_Train                              0.822695  0.975275
# LogisticRegression_Scaled_With_Smote_Test   0.931129  0.975160
# Logit_SM_Test_SMOTE                         0.944418  0.974799
# LogisticRegression_With_Smote_Train         0.938189  0.972807
# LogisticRegression_With_Smote_Test          0.934928  0.968668
# LogisticRegression_Unscaled_Train           0.863071  0.966442
# Logit_SM_Test                               0.802817  0.956256
# LogisticRegression_Unscaled_Test            0.794872  0.945725
# LogisticRegression_Scaled_Test              0.755365  0.945098
# LDA_Train                                   0.022642  0.740082
# LDA_With_Smote_Train                        0.710191  0.724862
# LDA_With_Smote_Test                         0.695265  0.702944
# LDA_Test                                    0.044118  0.683203

# %% [markdown]
# ## Best Model on Train Data

# %%
data_df[0::2].sort_values(by='Accuracy',ascending=False)
# Out:
#                                             Accuracy Precision    Recall  \
# RandomForest_Train                          0.981242  0.924603  0.899614
# RF_With_Smote_Train                         0.979678   0.98535  0.973844
# LogisticRegression_Unscaled_Train           0.972489  0.932735  0.803089
# LogisticRegression_Scaled_Train             0.964569  0.943878  0.714286
# Logit_SM_Train                              0.958316  0.760656  0.895753
# Logit_SM_Train_SMOTE                        0.950245  0.979125  0.920131
# LogisticRegression_With_Smote_Train         0.939734  0.963109  0.914526
# LogisticRegression_Scaled_With_Smote_Train  0.936697  0.917038  0.960299
# LDA_Train                                   0.892038       0.5  0.011583
# LDA_With_Smote_Train                        0.659893    0.6188  0.833255
#
#                                                    F1       AUC
# RandomForest_Train                           0.911937   0.99399
# RF_With_Smote_Train                          0.979563  0.998354
# LogisticRegression_Unscaled_Train            0.863071  0.966442
# LogisticRegression_Scaled_Train              0.813187   0.97694
# Logit_SM_Train                               0.822695  0.975275
# Logit_SM_Train_SMOTE                         0.948712  0.981177
# LogisticRegression_With_Smote_Train          0.938189  0.972807
# LogisticRegression_Scaled_With_Smote_Train    0.93817  0.982349
# LDA_Train                                   0.0226415  0.740082
# LDA_With_Smote_Train                         0.710191  0.724862

# %% [markdown]
# ## Best Model on Test Data

# %%
data_df[1::2].sort_values(by='Accuracy',ascending=False)
# Out:
#                                            Accuracy Precision    Recall  \
# RandomForest_Test                          0.974619  0.907563  0.850394
# RF_With_Smote_Test                         0.970128   0.97056  0.969639
# LogisticRegression_Unscaled_Test           0.959391  0.869159  0.732283
# Logit_SM_Test                              0.952623  0.726115  0.897638
# LogisticRegression_Scaled_Test             0.951777  0.830189  0.692913
# Logit_SM_Test_SMOTE                        0.945472  0.962562  0.926945
# LogisticRegression_With_Smote_Test         0.935514   0.94305  0.926945
# LogisticRegression_Scaled_With_Smote_Test  0.928876  0.902135  0.962049
# LDA_Test                                   0.890017  0.333333  0.023622
# LDA_With_Smote_Test                        0.642959   0.60621  0.814991
#
#                                                   F1       AUC
# RandomForest_Test                           0.878049  0.985857
# RF_With_Smote_Test                            0.9701  0.996038
# LogisticRegression_Unscaled_Test            0.794872  0.945725
# Logit_SM_Test                               0.802817  0.956256
# LogisticRegression_Scaled_Test              0.755365  0.945098
# Logit_SM_Test_SMOTE                         0.944418  0.974799
# LogisticRegression_With_Smote_Test          0.934928  0.968668
# LogisticRegression_Scaled_With_Smote_Test   0.931129   0.97516
# LDA_Test                                   0.0441176  0.683203
# LDA_With_Smote_Test                         0.695265  0.702944

# %%
data_df['Accuracy']
# Out:
# Logit_SM_Train                                0.958316
# Logit_SM_Test                                 0.952623
# Logit_SM_Train_SMOTE                          0.950245
# Logit_SM_Test_SMOTE                           0.945472
# LogisticRegression_Unscaled_Train             0.972489
# LogisticRegression_Unscaled_Test              0.959391
# LogisticRegression_Scaled_Train               0.964569
# LogisticRegression_Scaled_Test                0.951777
# LogisticRegression_With_Smote_Train           0.939734
# LogisticRegression_With_Smote_Test            0.935514
# LogisticRegression_Scaled_With_Smote_Train    0.936697
# LogisticRegression_Scaled_With_Smote_Test     0.928876
# LDA_Train                                     0.892038
# LDA_Test                                      0.890017
# LDA_With_Smote_Train                          0.659893
# LDA_With_Smote_Test                           0.642959
# RandomForest_Train                            0.981242
# RandomForest_Test                             0.974619
# RF_With_Smote_Train                           0.979678
# RF_With_Smote_Test                            0.970128
# Name: Accuracy, dtype: object

# %%
data_df_org=data_df.copy()

# %%
data_df.Accuracy=data_df.Accuracy.astype(float)

# %%
data_df.Precision=data_df.Precision.astype(float)
data_df.Recall=data_df.Recall.astype(float)
data_df.F1=data_df.F1.astype(float)
data_df.AUC=data_df.AUC.astype(float)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Logit_SM_Train to RF_With_Smote_Test
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Accuracy   20 non-null     float64
#  1   Precision  20 non-null     float64
#  2   Recall     20 non-null     float64
#  3   F1         20 non-null     float64
#  4   AUC        20 non-null     float64
# dtypes: float64(5)
# memory usage: 1.6+ KB

# %% [markdown]
# # Comparison

# %%
plt.figure(figsize=(10,10))
sns.lineplot(data=data_df[0::2].T,dashes=False)

# %%
plt.figure(figsize=(10,10))
sns.lineplot(data=data_df[1::2].T,dashes=False)
